# %% [markdown]
# # Processar lista do TRE e extrair código do processo

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

import time
import pyodbc
from sqlalchemy import create_engine, event
#from urllib.parse import quote_plus

from pathlib import Path
import pdfplumber
import re

# %% [markdown]
# ## Criar dataframe a partir da planilha

# %%
filename = "LISTA-TRE-ATUALIZADA-14-08-2020"
df = pd.read_excel(f"{filename}.xlsx")

# %%
df.head()
# Out:
#    ANO DO JULGAMENTO  DECISÃO   DATA DO JULGAMENTO        PROCESSO  \
# 0             2011.0   546/11  2011-05-19 00:00:00  TC-E 40.660/09
# 1             2011.0  1434/11  2011-12-01 00:00:00  TC-E 15.100/10
# 2             2011.0    47/11  2011-01-13 00:00:00  TC-E 22.557/09
# 3             2011.0  1458/11  2011-12-07 00:00:00  TC-E 16.248/10
# 4             2011.0   733/10  2011-06-16 00:00:00  TC-E 12.462/08
#
#        MUNICÍPIO/ENTE             ÓRGÃO EXERCÍCIO                    GESTOR  \
# 0  ALAGOINHA DO PIAUÍ  CÂMARA MUNICIPAL      2008    ABELARDO ANTÔNIO DE SÁ
# 1      LAGOA DO SÍTIO  CÂMARA MUNICIPAL      2009  ABIMAR SOARES LIMA VERDE
# 2    RIBEIRA DO PIAUÍ               FMS      2008            ADÃO LIRA LEAL
# 3    RIBEIRA DO PIAUÍ               FMS      2009            ADÃO LIRA LEAL
# 4               COCAL  CÂMARA MUNICIPAL      2007    ADERSON NOGUEIRA RAMOS
#
#    CPF       RESULTADO DATA DO TRANSITO EM JULGADO  DATA DA INCLUSÃO NA LISTA  \
# 0  NaN  IRREGULARIDADE                          NaN                       NaT
# 1  NaN  IRREGULARIDADE                          NaN                       NaT
# 2  NaN  IRREGULARIDADE                          NaN                       NaT
# 3  NaN  IRREGULARIDADE                          NaN                       NaT
# 4  NaN  IRREGULARIDADE                          NaN                       NaT
#
#   Unnamed: 12 Unnamed: 13
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df.shape
# Out:
# (2366, 14)

# %% [markdown]
# ## Fazer limpeza dos dados

# %%
# Remover registros sem processo
df.dropna(axis=0, subset=['PROCESSO'], inplace=True)
df.shape
# Out:
# (2332, 14)

# %%
df.columns
# Out:
# Index(['ANO DO JULGAMENTO', 'DECISÃO', 'DATA DO JULGAMENTO', 'PROCESSO',
#        'MUNICÍPIO/ENTE', 'ÓRGÃO', 'EXERCÍCIO', 'GESTOR', 'CPF', 'RESULTADO',
#        'DATA DO TRANSITO EM JULGADO ', 'DATA DA INCLUSÃO NA LISTA',
#        'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
# Remover colunas excedentes
df.drop(["Unnamed: 12", "Unnamed: 13"], axis=1, inplace=True)

# %% [markdown]
# ## Extrair coluna cod_TCE a partir da coluna processo

# %%
# Testar 
pattern = r"[\d.]+/\d+"

processo = 'TC/52917/2012'
processo2 = 'TC-E 39290/12'
processo3 = 'TC-E/12'
print(re.search(pattern, processo).group(0))
print(re.search(pattern, processo2).group(0))
match = re.search(pattern, processo3)
type(match)
# Out:
# 52917/2012
# 39290/12
# NoneType

# %%
def extrai_cod_tce(processo):
    pattern = r"[\d.]+/\d+"  # Apenas digitos ou ponto seguido por / e digitos
    
    #print(processo)
    match = re.search(pattern, processo)
    if match:
        cod_tce = re.search(pattern, processo).group(0)
        numero, ano = cod_tce.split('/')
        numero = numero.replace('.', '')
        if len(ano) == 2:
            ano = '20' + ano
        cod_tce = str(numero).zfill(6) + '/' + ano
        return cod_tce

# %%
print(extrai_cod_tce('TC/52917/2012'))
# Out:
# 052917/2012

# %%
print(extrai_cod_tce('TC/2012'))
# Out:
# None

# %%
print(str('52917').zfill(6))
# Out:
# 052917

# %%
extrai_cod_tce(df.iloc[0].PROCESSO)
# Out:
# '040660/2009'

# %%
df['COD_TCE'] = df['PROCESSO'].apply(lambda x: extrai_cod_tce(x))

# %%
df
# Out:
#       ANO DO JULGAMENTO           DECISÃO   DATA DO JULGAMENTO  \
# 0                2011.0            546/11  2011-05-19 00:00:00
# 1                2011.0           1434/11  2011-12-01 00:00:00
# 2                2011.0             47/11  2011-01-13 00:00:00
# 3                2011.0           1458/11  2011-12-07 00:00:00
# 4                2011.0            733/10  2011-06-16 00:00:00
# ...                 ...               ...                  ...
# 2340             2019.0  1.666/2019 (R.R)  2019-09-19 00:00:00
# 2341             2020.0    179/2020 (R.R)  2020-02-06 00:00:00
# 2342             2020.0    180/2020 (R.R)  2020-02-06 00:00:00
# 2343             2020.0    267/2020 (R.R)  2020-02-20 00:00:00
# 2344             2020.0    181/2020 (R.R)  2020-02-06 00:00:00
#
#             PROCESSO      MUNICÍPIO/ENTE  \
# 0     TC-E 40.660/09  ALAGOINHA DO PIAUÍ
# 1     TC-E 15.100/10      LAGOA DO SÍTIO
# 2     TC-E 22.557/09    RIBEIRA DO PIAUÍ
# 3     TC-E 16.248/10    RIBEIRA DO PIAUÍ
# 4     TC-E 12.462/08               COCAL
# ...              ...                 ...
# 2340  TC/012133/2019              SECULT
# 2341  TC/019012/2018            ITAUEIRA
# 2342  TC/019014/2018            ITAUEIRA
# 2343  TC/019016/2018            ITAUEIRA
# 2344  TC/019015/2018            ITAUEIRA
#
#                                                   ÓRGÃO EXERCÍCIO  \
# 0                                      CÂMARA MUNICIPAL      2008
# 1                                      CÂMARA MUNICIPAL      2009
# 2                                                   FMS      2008
# 3                                                   FMS      2009
# 4                                      CÂMARA MUNICIPAL      2007
# ...                                                 ...       ...
# 2340  SECRETARIA DE CULTURA DO ESTADO DO PIAUÍ - SECULT      2015
# 2341                                               FMS       2016
# 2342                                             FUNDEB      2016
# 2343                               PREFEITURA - GOVERNO      2016
# 2344                                PREFEITURA - GESTÃO      2016
#
#                                GESTOR             CPF       RESULTADO  \
# 0              ABELARDO ANTÔNIO DE SÁ             NaN  IRREGULARIDADE
# 1            ABIMAR SOARES LIMA VERDE             NaN  IRREGULARIDADE
# 2                      ADÃO LIRA LEAL             NaN  IRREGULARIDADE
# 3                      ADÃO LIRA LEAL             NaN  IRREGULARIDADE
# 4              ADERSON NOGUEIRA RAMOS             NaN  IRREGULARIDADE
# ...                               ...             ...             ...
# 2340  JACEMIA FEITOSA DE SOUSA DANTAS  774.696.313-72  IRREGULARIDADE
# 2341       QUIRINO DE ALENCAR AVELINO  022.473.213-72  IRREGULARIDADE
# 2342       QUIRINO DE ALENCAR AVELINO  022.473.213-72  IRREGULARIDADE
# 2343       QUIRINO DE ALENCAR AVELINO  022.473.213-72      REPROVAÇÃO
# 2344       QUIRINO DE ALENCAR AVELINO  022.473.213-72  IRREGULARIDADE
#
#      DATA DO TRANSITO EM JULGADO  DATA DA INCLUSÃO NA LISTA      COD_TCE
# 0                             NaN                       NaT  040660/2009
# 1                             NaN                       NaT  015100/2010
# 2                             NaN                       NaT  022557/2009
# 3                             NaN                       NaT  016248/2010
# 4                             NaN                       NaT  012462/2008
# ...                           ...                       ...          ...
# 2340          2020-03-10 00:00:00                       NaT  012133/2019
# 2341          2020-03-12 00:00:00                       NaT  019012/2018
# 2342          2020-03-12 00:00:00                       NaT  019014/2018
# 2343          2020-05-13 00:00:00                       NaT  019016/2018
# 2344          2020-05-08 00:00:00                       NaT  019015/2018
#
# [2332 rows x 13 columns]

# %% [markdown]
# ### Exportar dados para csv

# %%
df.to_csv(filename + "com-cod_tce.csv", sep=";", encoding="UTF-8")

# %% [markdown]
# ## Salvar dataframe em banco de dados
#
# Dica encontrada [aqui](https://www.it-swarm-pt.tech/pt/python/acelerando-pandas.dataframe.to-sql-com-fast-executemany-de-pyodbc/836846743/)

# %%
conn =  "DRIVER={SQL Server Native Client 11.0};SERVER=LUA;DATABASE=etcev2?trusted_connection=yes"
engine = create_engine('mssql+pyodbc://LUA/etcev2?trusted_connection=yes&driver=ODBC+Driver+13+for+SQL+Server')

# %%
@event.listens_for(engine, 'before_cursor_execute')
def receive_before_cursor_execute(conn, cursor, statement, params, context, executemany):
    print("FUNC call")
    if executemany:
        cursor.fast_executemany = True

nome_tabela_BD = 'tcepi.' + filename
s = time.time()
acao_se_existir = 'replace' # replace: Drop the table before inserting new values.
df.to_sql(nome_tabela_BD, engine, schema='tcepi', if_exists = acao_se_existir, index=False, chunksize = None)
print(time.time() - s)
# Out:
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# FUNC call
# 5.5962605476379395

# %% [markdown]
# ## Buscar registros de tabela salva em BD

# %%
query = """
select p.cod_TCE, p.assunto, pp.ordem as peca, a.descricao, ta.descricao tipo_ato, ad.caminho
from etce.protocolo p join etce.processo pc on pc.cod_protocolo = p.cod
	join etce.peca_processo pp on pp.cod_processo = pc.cod
	join etce.ato a on a.cod_protocolo = p.cod 
		and a.cod = pp.cod_ato
		and a.cod_tipo_ato in (2, 3, 75)
		and a.data_finalizacao is not null --a.cod_situacao =410
	join etce.tipo_ato ta on ta.cod = a.cod_tipo_ato
	join etce.arquivo_digital ad on ad.cod = a.cod_arquivo_digital
	join [tcepi].[tcepi.LISTA-TRE-ATUALIZADA-14-08-2020] tre on tre.COD_TCE = p.cod_tce
order by p.ano_oficio, cod_TCE, peca
"""

# %%
df_tre = pd.read_sql(query, engine)

# %%
df_tre
# Out:
#           cod_TCE                                            assunto  peca  \
# 0     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 1     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 2     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 3     052940/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    50
# 4     052941/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    50
# ...           ...                                                ...   ...
# 4364  019160/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    16
# 4365  019161/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    16
# 4366  019162/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    13
# 4367  020232/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/003137/20...    13
# 4368  021550/2019   RECURSO DE RECONSIDERAÇÃO REF. AO TC/003310/2016    13
#
#                              descricao           tipo_ato  \
# 0     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 1     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 2     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 3              ACO - G.WA  -  152/2015            ACÓRDÃO
# 4           ACOCAM - AUD4  -  543/2016  ACÓRDÃO DE CÂMARA
# ...                                ...                ...
# 4364    ACOPLE - GLUCIANO  -  481/2020   ACÓRDÃO DO PLENO
# 4365    ACOPLE - GLUCIANO  -  480/2020   ACÓRDÃO DO PLENO
# 4366    ACOPLE - GLUCIANO  -  482/2020   ACÓRDÃO DO PLENO
# 4367  ACOPLE - AUD-DELANO  -  362/2020   ACÓRDÃO DO PLENO
# 4368     ACOPLE - GREBELO  -  225/2020   ACÓRDÃO DO PLENO
#
#                                                 caminho
# 0              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 1              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 2              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 3                  /2015/12/609773/8/75/781temp/ACO.pdf
# 4              /2016/06/609774/121/2/252temp/ACOCAM.pdf
# ...                                                 ...
# 4364  /2020/01/767691/12/3/31012020_101644_08F0E4782...
# 4365  /2020/01/767692/12/3/31012020_101437_BC2F5999B...
# 4366  /2020/01/767693/12/3/31012020_101841_2391030D9...
# 4367  /2020/02//768763/120/3/12022020_103207_13CB26B...
# 4368  /2020/02//770081/13/3/11022020_141438_57ED7C7A...
#
# [4369 rows x 6 columns]

# %% [markdown]
# ## Extrair textos dos acórdãos a partir do PDF

# %%
def caminho_incial(ano):
    if int(ano) >= 2020:
        return "//alya/ftpd$/etce/"
    else :
        caminhos = {"2012": "//alya/ftpd$/etce/", \
                    "2013": "//alya/ftpf$/etce/", \
                    "2014": "//alya/ftpf$/etce/", \
                    "2015": "//alya/ftpf$/etce/", \
                    "2016": "//alya/ftpd$/etce/", \
                    "2017": "//alya/ftpd$/etce/", \
                    "2018": "//alya/ftpd$/etce/", \
                    "2019": "//alya/ftpg$/etce/"}
        return caminhos[ano]

def extrai_acordao(path):
    texto = ''
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            texto = texto + page.extract_text()
    
    return texto

# %%
df_tre['texto'] = ''
df_tre
# Out:
#           cod_TCE                                            assunto  peca  \
# 0     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 1     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 2     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 3     052940/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    50
# 4     052941/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    50
# ...           ...                                                ...   ...
# 4364  019160/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    16
# 4365  019161/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    16
# 4366  019162/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    13
# 4367  020232/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/003137/20...    13
# 4368  021550/2019   RECURSO DE RECONSIDERAÇÃO REF. AO TC/003310/2016    13
#
#                              descricao           tipo_ato  \
# 0     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 1     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 2     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 3              ACO - G.WA  -  152/2015            ACÓRDÃO
# 4           ACOCAM - AUD4  -  543/2016  ACÓRDÃO DE CÂMARA
# ...                                ...                ...
# 4364    ACOPLE - GLUCIANO  -  481/2020   ACÓRDÃO DO PLENO
# 4365    ACOPLE - GLUCIANO  -  480/2020   ACÓRDÃO DO PLENO
# 4366    ACOPLE - GLUCIANO  -  482/2020   ACÓRDÃO DO PLENO
# 4367  ACOPLE - AUD-DELANO  -  362/2020   ACÓRDÃO DO PLENO
# 4368     ACOPLE - GREBELO  -  225/2020   ACÓRDÃO DO PLENO
#
#                                                 caminho texto
# 0              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 1              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 2              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 3                  /2015/12/609773/8/75/781temp/ACO.pdf
# 4              /2016/06/609774/121/2/252temp/ACOCAM.pdf
# ...                                                 ...   ...
# 4364  /2020/01/767691/12/3/31012020_101644_08F0E4782...
# 4365  /2020/01/767692/12/3/31012020_101437_BC2F5999B...
# 4366  /2020/01/767693/12/3/31012020_101841_2391030D9...
# 4367  /2020/02//768763/120/3/12022020_103207_13CB26B...
# 4368  /2020/02//770081/13/3/11022020_141438_57ED7C7A...
#
# [4369 rows x 7 columns]

# %%
for ind in df_tre.index: 
    path = Path(caminho_incial((df_tre["caminho"][ind])[1:5]) + df_tre["caminho"][ind])
    if path.exists():
        print(f'Extraindo texto de acórdão {ind+1} de {len(df_tre)}')
        texto = extrai_acordao(path)
        df_tre.at[ind, 'texto'] = texto
    else:
        print(f'Arquivo inexistente de acórdão {ind+1} de {len(df_tre)}. Caminho: {path}')
# Out:
# Extraindo texto de acórdão 1 de 4369
# Extraindo texto de acórdão 2 de 4369
# Extraindo texto de acórdão 3 de 4369
# Extraindo texto de acórdão 4 de 4369
# Extraindo texto de acórdão 5 de 4369
# Extraindo texto de acórdão 6 de 4369
# Extraindo texto de acórdão 7 de 4369
# Extraindo texto de acórdão 8 de 4369
# Extraindo texto de acórdão 9 de 4369
# Extraindo texto de acórdão 10 de 4369
# Extraindo texto de acórdão 11 de 4369
# Extraindo texto de acórdão 12 de 4369
# Extraindo texto de acórdão 13 de 4369
# Extraindo texto de acórdão 14 de 4369
# Extraindo texto de acórdão 15 de 4369
# Extraindo texto de acórdão 16 de 4369
# Extraindo texto de acórdão 17 de 4369
# Extraindo texto de acórdão 18 de 4369
# Extraindo texto de acórdão 19 de 4369
# Extraindo texto de acórdão 20 de 4369
# Extraindo texto de acórdão 21 de 4369
# Extraindo texto de acórdão 22 de 4369
# Extraindo texto de acórdão 23 de 4369
# Extraindo texto de acórdão 24 de 4369
# Extraindo texto de acórdão 25 de 4369
# Extraindo texto de acórdão 26 de 4369
# Extraindo texto de acórdão 27 de 4369
# Extraindo texto de acórdão 28 de 4369
# Extraindo texto de acórdão 29 de 4369
# Extraindo texto de acórdão 30 de 4369
# Extraindo texto de acórdão 31 de 4369
# Extraindo texto de acórdão 32 de 4369
# Extraindo texto de acórdão 33 de 4369
# Extraindo texto de acórdão 34 de 4369
# Extraindo texto de acórdão 35 de 4369
# Extraindo texto de acórdão 36 de 4369
# Extraindo texto de acórdão 37 de 4369
# Extraindo texto de acórdão 38 de 4369
# Extraindo texto de acórdão 39 de 4369
# Extraindo texto de acórdão 40 de 4369
# Extraindo texto de acórdão 41 de 4369
# Extraindo texto de acórdão 42 de 4369
# Extraindo texto de acórdão 43 de 4369
# Extraindo texto de acórdão 44 de 4369
# Extraindo texto de acórdão 45 de 4369
# Extraindo texto de acórdão 46 de 4369
# Extraindo texto de acórdão 47 de 4369
# Extraindo texto de acórdão 48 de 4369
# Extraindo texto de acórdão 49 de 4369
# Extraindo texto de acórdão 50 de 4369
# Extraindo texto de acórdão 51 de 4369
# Extraindo texto de acórdão 52 de 4369
# Extraindo texto de acórdão 53 de 4369
# Extraindo texto de acórdão 54 de 4369
# Extraindo texto de acórdão 55 de 4369
# Extraindo texto de acórdão 56 de 4369
# Extraindo texto de acórdão 57 de 4369
# Extraindo texto de acórdão 58 de 4369
# Extraindo texto de acórdão 59 de 4369
# Extraindo texto de acórdão 60 de 4369
# Extraindo texto de acórdão 61 de 4369
# Extraindo texto de acórdão 62 de 4369
# Extraindo texto de acórdão 63 de 4369
# Extraindo texto de acórdão 64 de 4369
# Extraindo texto de acórdão 65 de 4369
# Extraindo texto de acórdão 66 de 4369
# Extraindo texto de acórdão 67 de 4369
# Extraindo texto de acórdão 68 de 4369
# Extraindo texto de acórdão 69 de 4369
# Extraindo texto de acórdão 70 de 4369
# Extraindo texto de acórdão 71 de 4369
# Extraindo texto de acórdão 72 de 4369
# Extraindo texto de acórdão 73 de 4369
# Extraindo texto de acórdão 74 de 4369
# Extraindo texto de acórdão 75 de 4369
# Extraindo texto de acórdão 76 de 4369
# Extraindo texto de acórdão 77 de 4369
# Extraindo texto de acórdão 78 de 4369
# Extraindo texto de acórdão 79 de 4369
# Extraindo texto de acórdão 80 de 4369
# Extraindo texto de acórdão 81 de 4369
# Extraindo texto de acórdão 82 de 4369
# Extraindo texto de acórdão 83 de 4369
# Extraindo texto de acórdão 84 de 4369
# Extraindo texto de acórdão 85 de 4369
# Extraindo texto de acórdão 86 de 4369
# Extraindo texto de acórdão 87 de 4369
# Extraindo texto de acórdão 88 de 4369
# Extraindo texto de acórdão 89 de 4369
# Extraindo texto de acórdão 90 de 4369
# Extraindo texto de acórdão 91 de 4369
# Extraindo texto de acórdão 92 de 4369
# Extraindo texto de acórdão 93 de 4369
# Extraindo texto de acórdão 94 de 4369
# Extraindo texto de acórdão 95 de 4369
# Extraindo texto de acórdão 96 de 4369
# Extraindo texto de acórdão 97 de 4369
# Extraindo texto de acórdão 98 de 4369
# Extraindo texto de acórdão 99 de 4369
# Extraindo texto de acórdão 100 de 4369
# Extraindo texto de acórdão 101 de 4369
# Extraindo texto de acórdão 102 de 4369
# Extraindo texto de acórdão 103 de 4369
# Extraindo texto de acórdão 104 de 4369
# Extraindo texto de acórdão 105 de 4369
# Extraindo texto de acórdão 106 de 4369
# Extraindo texto de acórdão 107 de 4369
# Extraindo texto de acórdão 108 de 4369
# Extraindo texto de acórdão 109 de 4369
# Extraindo texto de acórdão 110 de 4369
# Extraindo texto de acórdão 111 de 4369
# Extraindo texto de acórdão 112 de 4369
# Extraindo texto de acórdão 113 de 4369
# Extraindo texto de acórdão 114 de 4369
# Extraindo texto de acórdão 115 de 4369
# Extraindo texto de acórdão 116 de 4369
# Extraindo texto de acórdão 117 de 4369
# Extraindo texto de acórdão 118 de 4369
# Extraindo texto de acórdão 119 de 4369
# Extraindo texto de acórdão 120 de 4369
# Extraindo texto de acórdão 121 de 4369
# Extraindo texto de acórdão 122 de 4369
# Extraindo texto de acórdão 123 de 4369
# Extraindo texto de acórdão 124 de 4369
# Extraindo texto de acórdão 125 de 4369
# Extraindo texto de acórdão 126 de 4369
# Extraindo texto de acórdão 127 de 4369
# Extraindo texto de acórdão 128 de 4369
# Extraindo texto de acórdão 129 de 4369
# Extraindo texto de acórdão 130 de 4369
# Extraindo texto de acórdão 131 de 4369
# Extraindo texto de acórdão 132 de 4369
# Extraindo texto de acórdão 133 de 4369
# Extraindo texto de acórdão 134 de 4369
# Extraindo texto de acórdão 135 de 4369
# Extraindo texto de acórdão 136 de 4369
# Extraindo texto de acórdão 137 de 4369
# Extraindo texto de acórdão 138 de 4369
# Extraindo texto de acórdão 139 de 4369
# Extraindo texto de acórdão 140 de 4369
# Extraindo texto de acórdão 141 de 4369
# Extraindo texto de acórdão 142 de 4369
# Extraindo texto de acórdão 143 de 4369
# Extraindo texto de acórdão 144 de 4369
# Extraindo texto de acórdão 145 de 4369
# Extraindo texto de acórdão 146 de 4369
# Extraindo texto de acórdão 147 de 4369
# Extraindo texto de acórdão 148 de 4369
# Extraindo texto de acórdão 149 de 4369
# Extraindo texto de acórdão 150 de 4369
# Extraindo texto de acórdão 151 de 4369
# Extraindo texto de acórdão 152 de 4369
# Extraindo texto de acórdão 153 de 4369
# Extraindo texto de acórdão 154 de 4369
# Extraindo texto de acórdão 155 de 4369
# Extraindo texto de acórdão 156 de 4369
# Extraindo texto de acórdão 157 de 4369
# Extraindo texto de acórdão 158 de 4369
# Extraindo texto de acórdão 159 de 4369
# Extraindo texto de acórdão 160 de 4369
# Extraindo texto de acórdão 161 de 4369
# Extraindo texto de acórdão 162 de 4369
# Extraindo texto de acórdão 163 de 4369
# Extraindo texto de acórdão 164 de 4369
# Extraindo texto de acórdão 165 de 4369
# Extraindo texto de acórdão 166 de 4369
# Extraindo texto de acórdão 167 de 4369
# Extraindo texto de acórdão 168 de 4369
# Extraindo texto de acórdão 169 de 4369
# Extraindo texto de acórdão 170 de 4369
# Extraindo texto de acórdão 171 de 4369
# Extraindo texto de acórdão 172 de 4369
# Extraindo texto de acórdão 173 de 4369
# Extraindo texto de acórdão 174 de 4369
# Extraindo texto de acórdão 175 de 4369
# Extraindo texto de acórdão 176 de 4369
# Extraindo texto de acórdão 177 de 4369
# Extraindo texto de acórdão 178 de 4369
# Extraindo texto de acórdão 179 de 4369
# Extraindo texto de acórdão 180 de 4369
# Extraindo texto de acórdão 181 de 4369
# Extraindo texto de acórdão 182 de 4369
# Extraindo texto de acórdão 183 de 4369
# Extraindo texto de acórdão 184 de 4369
# Extraindo texto de acórdão 185 de 4369
# Extraindo texto de acórdão 186 de 4369
# Extraindo texto de acórdão 187 de 4369
# Extraindo texto de acórdão 188 de 4369
# Extraindo texto de acórdão 189 de 4369
# Extraindo texto de acórdão 190 de 4369
# Extraindo texto de acórdão 191 de 4369
# Extraindo texto de acórdão 192 de 4369
# Extraindo texto de acórdão 193 de 4369
# Extraindo texto de acórdão 194 de 4369
# Extraindo texto de acórdão 195 de 4369
# Extraindo texto de acórdão 196 de 4369
# Extraindo texto de acórdão 197 de 4369
# Extraindo texto de acórdão 198 de 4369
# Extraindo texto de acórdão 199 de 4369
# Extraindo texto de acórdão 200 de 4369
# Extraindo texto de acórdão 201 de 4369
# Extraindo texto de acórdão 202 de 4369
# Extraindo texto de acórdão 203 de 4369
# Extraindo texto de acórdão 204 de 4369
# Extraindo texto de acórdão 205 de 4369
# Extraindo texto de acórdão 206 de 4369
# Extraindo texto de acórdão 207 de 4369
# Extraindo texto de acórdão 208 de 4369
# Extraindo texto de acórdão 209 de 4369
# Extraindo texto de acórdão 210 de 4369
# Extraindo texto de acórdão 211 de 4369
# Extraindo texto de acórdão 212 de 4369
# Extraindo texto de acórdão 213 de 4369
# Extraindo texto de acórdão 214 de 4369
# Extraindo texto de acórdão 215 de 4369
# Extraindo texto de acórdão 216 de 4369
# Extraindo texto de acórdão 217 de 4369
# Extraindo texto de acórdão 218 de 4369
# Extraindo texto de acórdão 219 de 4369
# Extraindo texto de acórdão 220 de 4369
# Extraindo texto de acórdão 221 de 4369
# Extraindo texto de acórdão 222 de 4369
# Extraindo texto de acórdão 223 de 4369
# Extraindo texto de acórdão 224 de 4369
# Extraindo texto de acórdão 225 de 4369
# Extraindo texto de acórdão 226 de 4369
# Extraindo texto de acórdão 227 de 4369
# Extraindo texto de acórdão 228 de 4369
# Extraindo texto de acórdão 229 de 4369
# Extraindo texto de acórdão 230 de 4369
# Extraindo texto de acórdão 231 de 4369
# Extraindo texto de acórdão 232 de 4369
# Extraindo texto de acórdão 233 de 4369
# Extraindo texto de acórdão 234 de 4369
# Extraindo texto de acórdão 235 de 4369
# Extraindo texto de acórdão 236 de 4369
# Extraindo texto de acórdão 237 de 4369
# Extraindo texto de acórdão 238 de 4369
# Extraindo texto de acórdão 239 de 4369
# Extraindo texto de acórdão 240 de 4369
# Extraindo texto de acórdão 241 de 4369
# Extraindo texto de acórdão 242 de 4369
# Extraindo texto de acórdão 243 de 4369
# Extraindo texto de acórdão 244 de 4369
# Extraindo texto de acórdão 245 de 4369
# Extraindo texto de acórdão 246 de 4369
# Extraindo texto de acórdão 247 de 4369
# Extraindo texto de acórdão 248 de 4369
# Extraindo texto de acórdão 249 de 4369
# Extraindo texto de acórdão 250 de 4369
# Extraindo texto de acórdão 251 de 4369
# Extraindo texto de acórdão 252 de 4369
# Extraindo texto de acórdão 253 de 4369
# Extraindo texto de acórdão 254 de 4369
# Extraindo texto de acórdão 255 de 4369
# Extraindo texto de acórdão 256 de 4369
# Extraindo texto de acórdão 257 de 4369
# Extraindo texto de acórdão 258 de 4369
# Extraindo texto de acórdão 259 de 4369
# Extraindo texto de acórdão 260 de 4369
# Extraindo texto de acórdão 261 de 4369
# Extraindo texto de acórdão 262 de 4369
# Extraindo texto de acórdão 263 de 4369
# Extraindo texto de acórdão 264 de 4369
# Extraindo texto de acórdão 265 de 4369
# Extraindo texto de acórdão 266 de 4369
# Extraindo texto de acórdão 267 de 4369
# Extraindo texto de acórdão 268 de 4369
# Extraindo texto de acórdão 269 de 4369
# Extraindo texto de acórdão 270 de 4369
# Extraindo texto de acórdão 271 de 4369
# Extraindo texto de acórdão 272 de 4369
# Extraindo texto de acórdão 273 de 4369
# Extraindo texto de acórdão 274 de 4369
# Extraindo texto de acórdão 275 de 4369
# Extraindo texto de acórdão 276 de 4369
# Extraindo texto de acórdão 277 de 4369
# Extraindo texto de acórdão 278 de 4369
# Extraindo texto de acórdão 279 de 4369
# Extraindo texto de acórdão 280 de 4369
# Extraindo texto de acórdão 281 de 4369
# Extraindo texto de acórdão 282 de 4369
# Extraindo texto de acórdão 283 de 4369
# Extraindo texto de acórdão 284 de 4369
# Extraindo texto de acórdão 285 de 4369
# Extraindo texto de acórdão 286 de 4369
# Extraindo texto de acórdão 287 de 4369
# Extraindo texto de acórdão 288 de 4369
# Extraindo texto de acórdão 289 de 4369
# Extraindo texto de acórdão 290 de 4369
# Extraindo texto de acórdão 291 de 4369
# Extraindo texto de acórdão 292 de 4369
# Extraindo texto de acórdão 293 de 4369
# Extraindo texto de acórdão 294 de 4369
# Extraindo texto de acórdão 295 de 4369
# Extraindo texto de acórdão 296 de 4369
# Extraindo texto de acórdão 297 de 4369
# Extraindo texto de acórdão 298 de 4369
# Extraindo texto de acórdão 299 de 4369
# Extraindo texto de acórdão 300 de 4369
# Extraindo texto de acórdão 301 de 4369
# Extraindo texto de acórdão 302 de 4369
# Extraindo texto de acórdão 303 de 4369
# Extraindo texto de acórdão 304 de 4369
# Extraindo texto de acórdão 305 de 4369
# Extraindo texto de acórdão 306 de 4369
# Extraindo texto de acórdão 307 de 4369
# Extraindo texto de acórdão 308 de 4369
# Extraindo texto de acórdão 309 de 4369
# Extraindo texto de acórdão 310 de 4369
# Extraindo texto de acórdão 311 de 4369
# Extraindo texto de acórdão 312 de 4369
# Extraindo texto de acórdão 313 de 4369
# Extraindo texto de acórdão 314 de 4369
# Extraindo texto de acórdão 315 de 4369
# Extraindo texto de acórdão 316 de 4369
# Extraindo texto de acórdão 317 de 4369
# Extraindo texto de acórdão 318 de 4369
# Extraindo texto de acórdão 319 de 4369
# Extraindo texto de acórdão 320 de 4369
# Extraindo texto de acórdão 321 de 4369
# Extraindo texto de acórdão 322 de 4369
# Extraindo texto de acórdão 323 de 4369
# Extraindo texto de acórdão 324 de 4369
# Extraindo texto de acórdão 325 de 4369
# Extraindo texto de acórdão 326 de 4369
# Extraindo texto de acórdão 327 de 4369
# Extraindo texto de acórdão 328 de 4369
# Extraindo texto de acórdão 329 de 4369
# Extraindo texto de acórdão 330 de 4369
# Extraindo texto de acórdão 331 de 4369
# Extraindo texto de acórdão 332 de 4369
# Extraindo texto de acórdão 333 de 4369
# Extraindo texto de acórdão 334 de 4369
# Extraindo texto de acórdão 335 de 4369
# Extraindo texto de acórdão 336 de 4369
# Extraindo texto de acórdão 337 de 4369
# Extraindo texto de acórdão 338 de 4369
# Extraindo texto de acórdão 339 de 4369
# Extraindo texto de acórdão 340 de 4369
# Extraindo texto de acórdão 341 de 4369
# Extraindo texto de acórdão 342 de 4369
# Extraindo texto de acórdão 343 de 4369
# Extraindo texto de acórdão 344 de 4369
# Extraindo texto de acórdão 345 de 4369
# Extraindo texto de acórdão 346 de 4369
# Extraindo texto de acórdão 347 de 4369
# Extraindo texto de acórdão 348 de 4369
# Extraindo texto de acórdão 349 de 4369
# Extraindo texto de acórdão 350 de 4369
# Extraindo texto de acórdão 351 de 4369
# Extraindo texto de acórdão 352 de 4369
# Extraindo texto de acórdão 353 de 4369
# Extraindo texto de acórdão 354 de 4369
# Extraindo texto de acórdão 355 de 4369
# Extraindo texto de acórdão 356 de 4369
# Extraindo texto de acórdão 357 de 4369
# Extraindo texto de acórdão 358 de 4369
# Extraindo texto de acórdão 359 de 4369
# Extraindo texto de acórdão 360 de 4369
# Extraindo texto de acórdão 361 de 4369
# Extraindo texto de acórdão 362 de 4369
# Extraindo texto de acórdão 363 de 4369
# Extraindo texto de acórdão 364 de 4369
# Extraindo texto de acórdão 365 de 4369
# Extraindo texto de acórdão 366 de 4369
# Extraindo texto de acórdão 367 de 4369
# Extraindo texto de acórdão 368 de 4369
# Extraindo texto de acórdão 369 de 4369
# Extraindo texto de acórdão 370 de 4369
# Extraindo texto de acórdão 371 de 4369
# Extraindo texto de acórdão 372 de 4369
# Extraindo texto de acórdão 373 de 4369
# Extraindo texto de acórdão 374 de 4369
# Extraindo texto de acórdão 375 de 4369
# Extraindo texto de acórdão 376 de 4369
# Extraindo texto de acórdão 377 de 4369
# Extraindo texto de acórdão 378 de 4369
# Extraindo texto de acórdão 379 de 4369
# Extraindo texto de acórdão 380 de 4369
# Extraindo texto de acórdão 381 de 4369
# Extraindo texto de acórdão 382 de 4369
# Extraindo texto de acórdão 383 de 4369
# Extraindo texto de acórdão 384 de 4369
# Extraindo texto de acórdão 385 de 4369
# Extraindo texto de acórdão 386 de 4369
# Extraindo texto de acórdão 387 de 4369
# Extraindo texto de acórdão 388 de 4369
# Extraindo texto de acórdão 389 de 4369
# Extraindo texto de acórdão 390 de 4369
# Extraindo texto de acórdão 391 de 4369
# Extraindo texto de acórdão 392 de 4369
# Extraindo texto de acórdão 393 de 4369
# Extraindo texto de acórdão 394 de 4369
# Extraindo texto de acórdão 395 de 4369
# Extraindo texto de acórdão 396 de 4369
# Extraindo texto de acórdão 397 de 4369
# Extraindo texto de acórdão 398 de 4369
# Extraindo texto de acórdão 399 de 4369
# Extraindo texto de acórdão 400 de 4369
# Extraindo texto de acórdão 401 de 4369
# Extraindo texto de acórdão 402 de 4369
# Extraindo texto de acórdão 403 de 4369
# Extraindo texto de acórdão 404 de 4369
# Extraindo texto de acórdão 405 de 4369
# Extraindo texto de acórdão 406 de 4369
# Extraindo texto de acórdão 407 de 4369
# Extraindo texto de acórdão 408 de 4369
# Extraindo texto de acórdão 409 de 4369
# Extraindo texto de acórdão 410 de 4369
# Extraindo texto de acórdão 411 de 4369
# Extraindo texto de acórdão 412 de 4369
# Extraindo texto de acórdão 413 de 4369
# Extraindo texto de acórdão 414 de 4369
# Extraindo texto de acórdão 415 de 4369
# Extraindo texto de acórdão 416 de 4369
# Extraindo texto de acórdão 417 de 4369
# Extraindo texto de acórdão 418 de 4369
# Extraindo texto de acórdão 419 de 4369
# Extraindo texto de acórdão 420 de 4369
# Extraindo texto de acórdão 421 de 4369
# Extraindo texto de acórdão 422 de 4369
# Extraindo texto de acórdão 423 de 4369
# Extraindo texto de acórdão 424 de 4369
# Extraindo texto de acórdão 425 de 4369
# Extraindo texto de acórdão 426 de 4369
# Extraindo texto de acórdão 427 de 4369
# Extraindo texto de acórdão 428 de 4369
# Extraindo texto de acórdão 429 de 4369
# Extraindo texto de acórdão 430 de 4369
# Extraindo texto de acórdão 431 de 4369
# Extraindo texto de acórdão 432 de 4369
# Extraindo texto de acórdão 433 de 4369
# Extraindo texto de acórdão 434 de 4369
# Extraindo texto de acórdão 435 de 4369
# Extraindo texto de acórdão 436 de 4369
# Extraindo texto de acórdão 437 de 4369
# Extraindo texto de acórdão 438 de 4369
# Extraindo texto de acórdão 439 de 4369
# Extraindo texto de acórdão 440 de 4369
# Extraindo texto de acórdão 441 de 4369
# Extraindo texto de acórdão 442 de 4369
# Extraindo texto de acórdão 443 de 4369
# Extraindo texto de acórdão 444 de 4369
# Extraindo texto de acórdão 445 de 4369
# Extraindo texto de acórdão 446 de 4369
# Extraindo texto de acórdão 447 de 4369
# Extraindo texto de acórdão 448 de 4369
# Extraindo texto de acórdão 449 de 4369
# Extraindo texto de acórdão 450 de 4369
# Extraindo texto de acórdão 451 de 4369
# Extraindo texto de acórdão 452 de 4369
# Extraindo texto de acórdão 453 de 4369
# Extraindo texto de acórdão 454 de 4369
# Extraindo texto de acórdão 455 de 4369
# Extraindo texto de acórdão 456 de 4369
# Extraindo texto de acórdão 457 de 4369
# Extraindo texto de acórdão 458 de 4369
# Extraindo texto de acórdão 459 de 4369
# Extraindo texto de acórdão 460 de 4369
# Extraindo texto de acórdão 461 de 4369
# Extraindo texto de acórdão 462 de 4369
# Extraindo texto de acórdão 463 de 4369
# Extraindo texto de acórdão 464 de 4369
# Extraindo texto de acórdão 465 de 4369
# Extraindo texto de acórdão 466 de 4369
# Extraindo texto de acórdão 467 de 4369
# Extraindo texto de acórdão 468 de 4369
# Extraindo texto de acórdão 469 de 4369
# Extraindo texto de acórdão 470 de 4369
# Extraindo texto de acórdão 471 de 4369
# Extraindo texto de acórdão 472 de 4369
# Extraindo texto de acórdão 473 de 4369
# Extraindo texto de acórdão 474 de 4369
# Extraindo texto de acórdão 475 de 4369
# Extraindo texto de acórdão 476 de 4369
# Extraindo texto de acórdão 477 de 4369
# Extraindo texto de acórdão 478 de 4369
# Extraindo texto de acórdão 479 de 4369
# Extraindo texto de acórdão 480 de 4369
# Extraindo texto de acórdão 481 de 4369
# Extraindo texto de acórdão 482 de 4369
# Extraindo texto de acórdão 483 de 4369
# Extraindo texto de acórdão 484 de 4369
# Extraindo texto de acórdão 485 de 4369
# Extraindo texto de acórdão 486 de 4369
# Extraindo texto de acórdão 487 de 4369
# Extraindo texto de acórdão 488 de 4369
# Extraindo texto de acórdão 489 de 4369
# Extraindo texto de acórdão 490 de 4369
# Extraindo texto de acórdão 491 de 4369
# Extraindo texto de acórdão 492 de 4369
# Extraindo texto de acórdão 493 de 4369
# Extraindo texto de acórdão 494 de 4369
# Extraindo texto de acórdão 495 de 4369
# Extraindo texto de acórdão 496 de 4369
# Extraindo texto de acórdão 497 de 4369
# Extraindo texto de acórdão 498 de 4369
# Extraindo texto de acórdão 499 de 4369
# Extraindo texto de acórdão 500 de 4369
# Extraindo texto de acórdão 501 de 4369
# Extraindo texto de acórdão 502 de 4369
# Extraindo texto de acórdão 503 de 4369
# Extraindo texto de acórdão 504 de 4369
# Extraindo texto de acórdão 505 de 4369
# Extraindo texto de acórdão 506 de 4369
# Extraindo texto de acórdão 507 de 4369
# Extraindo texto de acórdão 508 de 4369
# Extraindo texto de acórdão 509 de 4369
# Extraindo texto de acórdão 510 de 4369
# Extraindo texto de acórdão 511 de 4369
# Extraindo texto de acórdão 512 de 4369
# Extraindo texto de acórdão 513 de 4369
# Extraindo texto de acórdão 514 de 4369
# Extraindo texto de acórdão 515 de 4369
# Extraindo texto de acórdão 516 de 4369
# Extraindo texto de acórdão 517 de 4369
# Extraindo texto de acórdão 518 de 4369
# Extraindo texto de acórdão 519 de 4369
# Extraindo texto de acórdão 520 de 4369
# Extraindo texto de acórdão 521 de 4369
# Extraindo texto de acórdão 522 de 4369
# Extraindo texto de acórdão 523 de 4369
# Extraindo texto de acórdão 524 de 4369
# Extraindo texto de acórdão 525 de 4369
# Extraindo texto de acórdão 526 de 4369
# Extraindo texto de acórdão 527 de 4369
# Extraindo texto de acórdão 528 de 4369
# Extraindo texto de acórdão 529 de 4369
# Extraindo texto de acórdão 530 de 4369
# Extraindo texto de acórdão 531 de 4369
# Extraindo texto de acórdão 532 de 4369
# Extraindo texto de acórdão 533 de 4369
# Extraindo texto de acórdão 534 de 4369
# Extraindo texto de acórdão 535 de 4369
# Extraindo texto de acórdão 536 de 4369
# Extraindo texto de acórdão 537 de 4369
# Extraindo texto de acórdão 538 de 4369
# Extraindo texto de acórdão 539 de 4369
# Extraindo texto de acórdão 540 de 4369
# Extraindo texto de acórdão 541 de 4369
# Extraindo texto de acórdão 542 de 4369
# Extraindo texto de acórdão 543 de 4369
# Extraindo texto de acórdão 544 de 4369
# Extraindo texto de acórdão 545 de 4369
# Extraindo texto de acórdão 546 de 4369
# Extraindo texto de acórdão 547 de 4369
# Extraindo texto de acórdão 548 de 4369
# Extraindo texto de acórdão 549 de 4369
# Extraindo texto de acórdão 550 de 4369
# Extraindo texto de acórdão 551 de 4369
# Extraindo texto de acórdão 552 de 4369
# Extraindo texto de acórdão 553 de 4369
# Extraindo texto de acórdão 554 de 4369
# Extraindo texto de acórdão 555 de 4369
# Extraindo texto de acórdão 556 de 4369
# Extraindo texto de acórdão 557 de 4369
# Extraindo texto de acórdão 558 de 4369
# Extraindo texto de acórdão 559 de 4369
# Extraindo texto de acórdão 560 de 4369
# Extraindo texto de acórdão 561 de 4369
# Extraindo texto de acórdão 562 de 4369
# Extraindo texto de acórdão 563 de 4369
# Extraindo texto de acórdão 564 de 4369
# Extraindo texto de acórdão 565 de 4369
# Extraindo texto de acórdão 566 de 4369
# Extraindo texto de acórdão 567 de 4369
# Extraindo texto de acórdão 568 de 4369
# Extraindo texto de acórdão 569 de 4369
# Extraindo texto de acórdão 570 de 4369
# Extraindo texto de acórdão 571 de 4369
# Extraindo texto de acórdão 572 de 4369
# Extraindo texto de acórdão 573 de 4369
# Extraindo texto de acórdão 574 de 4369
# Extraindo texto de acórdão 575 de 4369
# Extraindo texto de acórdão 576 de 4369
# Extraindo texto de acórdão 577 de 4369
# Extraindo texto de acórdão 578 de 4369
# Extraindo texto de acórdão 579 de 4369
# Extraindo texto de acórdão 580 de 4369
# Extraindo texto de acórdão 581 de 4369
# Extraindo texto de acórdão 582 de 4369
# Extraindo texto de acórdão 583 de 4369
# Extraindo texto de acórdão 584 de 4369
# Extraindo texto de acórdão 585 de 4369
# Extraindo texto de acórdão 586 de 4369
# Extraindo texto de acórdão 587 de 4369
# Extraindo texto de acórdão 588 de 4369
# Extraindo texto de acórdão 589 de 4369
# Extraindo texto de acórdão 590 de 4369
# Extraindo texto de acórdão 591 de 4369
# Extraindo texto de acórdão 592 de 4369
# Extraindo texto de acórdão 593 de 4369
# Extraindo texto de acórdão 594 de 4369
# Extraindo texto de acórdão 595 de 4369
# Extraindo texto de acórdão 596 de 4369
# Extraindo texto de acórdão 597 de 4369
# Extraindo texto de acórdão 598 de 4369
# Extraindo texto de acórdão 599 de 4369
# Extraindo texto de acórdão 600 de 4369
# Extraindo texto de acórdão 601 de 4369
# Extraindo texto de acórdão 602 de 4369
# Extraindo texto de acórdão 603 de 4369
# Extraindo texto de acórdão 604 de 4369
# Extraindo texto de acórdão 605 de 4369
# Extraindo texto de acórdão 606 de 4369
# Extraindo texto de acórdão 607 de 4369
# Extraindo texto de acórdão 608 de 4369
# Extraindo texto de acórdão 609 de 4369
# Extraindo texto de acórdão 610 de 4369
# Extraindo texto de acórdão 611 de 4369
# Extraindo texto de acórdão 612 de 4369
# Extraindo texto de acórdão 613 de 4369
# Extraindo texto de acórdão 614 de 4369
# Extraindo texto de acórdão 615 de 4369
# Extraindo texto de acórdão 616 de 4369
# Extraindo texto de acórdão 617 de 4369
# Extraindo texto de acórdão 618 de 4369
# Extraindo texto de acórdão 619 de 4369
# Extraindo texto de acórdão 620 de 4369
# Extraindo texto de acórdão 621 de 4369
# Extraindo texto de acórdão 622 de 4369
# Extraindo texto de acórdão 623 de 4369
# Extraindo texto de acórdão 624 de 4369
# Extraindo texto de acórdão 625 de 4369
# Extraindo texto de acórdão 626 de 4369
# Extraindo texto de acórdão 627 de 4369
# Extraindo texto de acórdão 628 de 4369
# Extraindo texto de acórdão 629 de 4369
# Extraindo texto de acórdão 630 de 4369
# Extraindo texto de acórdão 631 de 4369
# Extraindo texto de acórdão 632 de 4369
# Extraindo texto de acórdão 633 de 4369
# Extraindo texto de acórdão 634 de 4369
# Extraindo texto de acórdão 635 de 4369
# Extraindo texto de acórdão 636 de 4369
# Extraindo texto de acórdão 637 de 4369
# Extraindo texto de acórdão 638 de 4369
# Extraindo texto de acórdão 639 de 4369
# Extraindo texto de acórdão 640 de 4369
# Extraindo texto de acórdão 641 de 4369
# Extraindo texto de acórdão 642 de 4369
# Extraindo texto de acórdão 643 de 4369
# Extraindo texto de acórdão 644 de 4369
# Extraindo texto de acórdão 645 de 4369
# Extraindo texto de acórdão 646 de 4369
# Extraindo texto de acórdão 647 de 4369
# Extraindo texto de acórdão 648 de 4369
# Extraindo texto de acórdão 649 de 4369
# Extraindo texto de acórdão 650 de 4369
# Extraindo texto de acórdão 651 de 4369
# Extraindo texto de acórdão 652 de 4369
# Extraindo texto de acórdão 653 de 4369
# Extraindo texto de acórdão 654 de 4369
# Extraindo texto de acórdão 655 de 4369
# Extraindo texto de acórdão 656 de 4369
# Extraindo texto de acórdão 657 de 4369
# Extraindo texto de acórdão 658 de 4369
# Extraindo texto de acórdão 659 de 4369
# Extraindo texto de acórdão 660 de 4369
# Extraindo texto de acórdão 661 de 4369
# Extraindo texto de acórdão 662 de 4369
# Extraindo texto de acórdão 663 de 4369
# Extraindo texto de acórdão 664 de 4369
# Extraindo texto de acórdão 665 de 4369
# Extraindo texto de acórdão 666 de 4369
# Extraindo texto de acórdão 667 de 4369
# Extraindo texto de acórdão 668 de 4369
# Extraindo texto de acórdão 669 de 4369
# Extraindo texto de acórdão 670 de 4369
# Extraindo texto de acórdão 671 de 4369
# Extraindo texto de acórdão 672 de 4369
# Extraindo texto de acórdão 673 de 4369
# Extraindo texto de acórdão 674 de 4369
# Extraindo texto de acórdão 675 de 4369
# Extraindo texto de acórdão 676 de 4369
# Extraindo texto de acórdão 677 de 4369
# Extraindo texto de acórdão 678 de 4369
# Extraindo texto de acórdão 679 de 4369
# Extraindo texto de acórdão 680 de 4369
# Extraindo texto de acórdão 681 de 4369
# Extraindo texto de acórdão 682 de 4369
# Extraindo texto de acórdão 683 de 4369
# Extraindo texto de acórdão 684 de 4369
# Extraindo texto de acórdão 685 de 4369
# Extraindo texto de acórdão 686 de 4369
# Extraindo texto de acórdão 687 de 4369
# Extraindo texto de acórdão 688 de 4369
# Extraindo texto de acórdão 689 de 4369
# Extraindo texto de acórdão 690 de 4369
# Extraindo texto de acórdão 691 de 4369
# Extraindo texto de acórdão 692 de 4369
# Extraindo texto de acórdão 693 de 4369
# Extraindo texto de acórdão 694 de 4369
# Extraindo texto de acórdão 695 de 4369
# Extraindo texto de acórdão 696 de 4369
# Extraindo texto de acórdão 697 de 4369
# Extraindo texto de acórdão 698 de 4369
# Extraindo texto de acórdão 699 de 4369
# Extraindo texto de acórdão 700 de 4369
# Extraindo texto de acórdão 701 de 4369
# Extraindo texto de acórdão 702 de 4369
# Extraindo texto de acórdão 703 de 4369
# Extraindo texto de acórdão 704 de 4369
# Extraindo texto de acórdão 705 de 4369
# Extraindo texto de acórdão 706 de 4369
# Extraindo texto de acórdão 707 de 4369
# Extraindo texto de acórdão 708 de 4369
# Extraindo texto de acórdão 709 de 4369
# Extraindo texto de acórdão 710 de 4369
# Extraindo texto de acórdão 711 de 4369
# Extraindo texto de acórdão 712 de 4369
# Extraindo texto de acórdão 713 de 4369
# Extraindo texto de acórdão 714 de 4369
# Extraindo texto de acórdão 715 de 4369
# Extraindo texto de acórdão 716 de 4369
# Extraindo texto de acórdão 717 de 4369
# Extraindo texto de acórdão 718 de 4369
# Extraindo texto de acórdão 719 de 4369
# Extraindo texto de acórdão 720 de 4369
# Extraindo texto de acórdão 721 de 4369
# Extraindo texto de acórdão 722 de 4369
# Extraindo texto de acórdão 723 de 4369
# Extraindo texto de acórdão 724 de 4369
# Extraindo texto de acórdão 725 de 4369
# Extraindo texto de acórdão 726 de 4369
# Extraindo texto de acórdão 727 de 4369
# Extraindo texto de acórdão 728 de 4369
# Extraindo texto de acórdão 729 de 4369
# Extraindo texto de acórdão 730 de 4369
# Extraindo texto de acórdão 731 de 4369
# Extraindo texto de acórdão 732 de 4369
# Extraindo texto de acórdão 733 de 4369
# Extraindo texto de acórdão 734 de 4369
# Extraindo texto de acórdão 735 de 4369
# Extraindo texto de acórdão 736 de 4369
# Extraindo texto de acórdão 737 de 4369
# Extraindo texto de acórdão 738 de 4369
# Extraindo texto de acórdão 739 de 4369
# Extraindo texto de acórdão 740 de 4369
# Extraindo texto de acórdão 741 de 4369
# Extraindo texto de acórdão 742 de 4369
# Extraindo texto de acórdão 743 de 4369
# Extraindo texto de acórdão 744 de 4369
# Extraindo texto de acórdão 745 de 4369
# Extraindo texto de acórdão 746 de 4369
# Extraindo texto de acórdão 747 de 4369
# Extraindo texto de acórdão 748 de 4369
# Extraindo texto de acórdão 749 de 4369
# Extraindo texto de acórdão 750 de 4369
# Extraindo texto de acórdão 751 de 4369
# Extraindo texto de acórdão 752 de 4369
# Extraindo texto de acórdão 753 de 4369
# Extraindo texto de acórdão 754 de 4369
# Extraindo texto de acórdão 755 de 4369
# Extraindo texto de acórdão 756 de 4369
# Extraindo texto de acórdão 757 de 4369
# Extraindo texto de acórdão 758 de 4369
# Extraindo texto de acórdão 759 de 4369
# Extraindo texto de acórdão 760 de 4369
# Extraindo texto de acórdão 761 de 4369
# Extraindo texto de acórdão 762 de 4369
# Extraindo texto de acórdão 763 de 4369
# Extraindo texto de acórdão 764 de 4369
# Extraindo texto de acórdão 765 de 4369
# Extraindo texto de acórdão 766 de 4369
# Extraindo texto de acórdão 767 de 4369
# Extraindo texto de acórdão 768 de 4369
# Extraindo texto de acórdão 769 de 4369
# Extraindo texto de acórdão 770 de 4369
# Extraindo texto de acórdão 771 de 4369
# Extraindo texto de acórdão 772 de 4369
# Extraindo texto de acórdão 773 de 4369
# Extraindo texto de acórdão 774 de 4369
# Extraindo texto de acórdão 775 de 4369
# Extraindo texto de acórdão 776 de 4369
# Extraindo texto de acórdão 777 de 4369
# Extraindo texto de acórdão 778 de 4369
# Extraindo texto de acórdão 779 de 4369
# Extraindo texto de acórdão 780 de 4369
# Extraindo texto de acórdão 781 de 4369
# Extraindo texto de acórdão 782 de 4369
# Extraindo texto de acórdão 783 de 4369
# Extraindo texto de acórdão 784 de 4369
# Extraindo texto de acórdão 785 de 4369
# Extraindo texto de acórdão 786 de 4369
# Extraindo texto de acórdão 787 de 4369
# Extraindo texto de acórdão 788 de 4369
# Extraindo texto de acórdão 789 de 4369
# Extraindo texto de acórdão 790 de 4369
# Extraindo texto de acórdão 791 de 4369
# Extraindo texto de acórdão 792 de 4369
# Extraindo texto de acórdão 793 de 4369
# Extraindo texto de acórdão 794 de 4369
# Extraindo texto de acórdão 795 de 4369
# Extraindo texto de acórdão 796 de 4369
# Extraindo texto de acórdão 797 de 4369
# Extraindo texto de acórdão 798 de 4369
# Extraindo texto de acórdão 799 de 4369
# Extraindo texto de acórdão 800 de 4369
# Extraindo texto de acórdão 801 de 4369
# Extraindo texto de acórdão 802 de 4369
# Extraindo texto de acórdão 803 de 4369
# Extraindo texto de acórdão 804 de 4369
# Extraindo texto de acórdão 805 de 4369
# Extraindo texto de acórdão 806 de 4369
# Extraindo texto de acórdão 807 de 4369
# Extraindo texto de acórdão 808 de 4369
# Extraindo texto de acórdão 809 de 4369
# Extraindo texto de acórdão 810 de 4369
# Extraindo texto de acórdão 811 de 4369
# Extraindo texto de acórdão 812 de 4369
# Extraindo texto de acórdão 813 de 4369
# Extraindo texto de acórdão 814 de 4369
# Extraindo texto de acórdão 815 de 4369
# Extraindo texto de acórdão 816 de 4369
# Extraindo texto de acórdão 817 de 4369
# Extraindo texto de acórdão 818 de 4369
# Extraindo texto de acórdão 819 de 4369
# Extraindo texto de acórdão 820 de 4369
# Extraindo texto de acórdão 821 de 4369
# Extraindo texto de acórdão 822 de 4369
# Extraindo texto de acórdão 823 de 4369
# Extraindo texto de acórdão 824 de 4369
# Extraindo texto de acórdão 825 de 4369
# Extraindo texto de acórdão 826 de 4369
# Extraindo texto de acórdão 827 de 4369
# Extraindo texto de acórdão 828 de 4369
# Extraindo texto de acórdão 829 de 4369
# Extraindo texto de acórdão 830 de 4369
# Extraindo texto de acórdão 831 de 4369
# Extraindo texto de acórdão 832 de 4369
# Extraindo texto de acórdão 833 de 4369
# Extraindo texto de acórdão 834 de 4369
# Extraindo texto de acórdão 835 de 4369
# Extraindo texto de acórdão 836 de 4369
# Extraindo texto de acórdão 837 de 4369
# Extraindo texto de acórdão 838 de 4369
# Extraindo texto de acórdão 839 de 4369
# Extraindo texto de acórdão 840 de 4369
# Extraindo texto de acórdão 841 de 4369
# Extraindo texto de acórdão 842 de 4369
# Extraindo texto de acórdão 843 de 4369
# Extraindo texto de acórdão 844 de 4369
# Extraindo texto de acórdão 845 de 4369
# Extraindo texto de acórdão 846 de 4369
# Extraindo texto de acórdão 847 de 4369
# Extraindo texto de acórdão 848 de 4369
# Extraindo texto de acórdão 849 de 4369
# Extraindo texto de acórdão 850 de 4369
# Extraindo texto de acórdão 851 de 4369
# Extraindo texto de acórdão 852 de 4369
# Extraindo texto de acórdão 853 de 4369
# Extraindo texto de acórdão 854 de 4369
# Extraindo texto de acórdão 855 de 4369
# Extraindo texto de acórdão 856 de 4369
# Extraindo texto de acórdão 857 de 4369
# Extraindo texto de acórdão 858 de 4369
# Extraindo texto de acórdão 859 de 4369
# Extraindo texto de acórdão 860 de 4369
# Extraindo texto de acórdão 861 de 4369
# Extraindo texto de acórdão 862 de 4369
# Extraindo texto de acórdão 863 de 4369
# Extraindo texto de acórdão 864 de 4369
# Extraindo texto de acórdão 865 de 4369
# Extraindo texto de acórdão 866 de 4369
# Extraindo texto de acórdão 867 de 4369
# Extraindo texto de acórdão 868 de 4369
# Extraindo texto de acórdão 869 de 4369
# Extraindo texto de acórdão 870 de 4369
# Extraindo texto de acórdão 871 de 4369
# Extraindo texto de acórdão 872 de 4369
# Extraindo texto de acórdão 873 de 4369
# Extraindo texto de acórdão 874 de 4369
# Extraindo texto de acórdão 875 de 4369
# Extraindo texto de acórdão 876 de 4369
# Extraindo texto de acórdão 877 de 4369
# Extraindo texto de acórdão 878 de 4369
# Extraindo texto de acórdão 879 de 4369
# Extraindo texto de acórdão 880 de 4369
# Extraindo texto de acórdão 881 de 4369
# Extraindo texto de acórdão 882 de 4369
# Extraindo texto de acórdão 883 de 4369
# Extraindo texto de acórdão 884 de 4369
# Extraindo texto de acórdão 885 de 4369
# Extraindo texto de acórdão 886 de 4369
# Extraindo texto de acórdão 887 de 4369
# Extraindo texto de acórdão 888 de 4369
# Extraindo texto de acórdão 889 de 4369
# Extraindo texto de acórdão 890 de 4369
# Extraindo texto de acórdão 891 de 4369
# Extraindo texto de acórdão 892 de 4369
# Extraindo texto de acórdão 893 de 4369
# Extraindo texto de acórdão 894 de 4369
# Extraindo texto de acórdão 895 de 4369
# Extraindo texto de acórdão 896 de 4369
# Extraindo texto de acórdão 897 de 4369
# Extraindo texto de acórdão 898 de 4369
# Extraindo texto de acórdão 899 de 4369
# Extraindo texto de acórdão 900 de 4369
# Extraindo texto de acórdão 901 de 4369
# Extraindo texto de acórdão 902 de 4369
# Extraindo texto de acórdão 903 de 4369
# Extraindo texto de acórdão 904 de 4369
# Extraindo texto de acórdão 905 de 4369
# Extraindo texto de acórdão 906 de 4369
# Extraindo texto de acórdão 907 de 4369
# Extraindo texto de acórdão 908 de 4369
# Extraindo texto de acórdão 909 de 4369
# Extraindo texto de acórdão 910 de 4369
# Extraindo texto de acórdão 911 de 4369
# Extraindo texto de acórdão 912 de 4369
# Extraindo texto de acórdão 913 de 4369
# Extraindo texto de acórdão 914 de 4369
# Extraindo texto de acórdão 915 de 4369
# Extraindo texto de acórdão 916 de 4369
# Extraindo texto de acórdão 917 de 4369
# Extraindo texto de acórdão 918 de 4369
# Extraindo texto de acórdão 919 de 4369
# Extraindo texto de acórdão 920 de 4369
# Extraindo texto de acórdão 921 de 4369
# Extraindo texto de acórdão 922 de 4369
# Extraindo texto de acórdão 923 de 4369
# Extraindo texto de acórdão 924 de 4369
# Extraindo texto de acórdão 925 de 4369
# Extraindo texto de acórdão 926 de 4369
# Extraindo texto de acórdão 927 de 4369
# Extraindo texto de acórdão 928 de 4369
# Extraindo texto de acórdão 929 de 4369
# Extraindo texto de acórdão 930 de 4369
# Extraindo texto de acórdão 931 de 4369
# Extraindo texto de acórdão 932 de 4369
# Extraindo texto de acórdão 933 de 4369
# Extraindo texto de acórdão 934 de 4369
# Extraindo texto de acórdão 935 de 4369
# Extraindo texto de acórdão 936 de 4369
# Extraindo texto de acórdão 937 de 4369
# Extraindo texto de acórdão 938 de 4369
# Extraindo texto de acórdão 939 de 4369
# Extraindo texto de acórdão 940 de 4369
# Extraindo texto de acórdão 941 de 4369
# Extraindo texto de acórdão 942 de 4369
# Extraindo texto de acórdão 943 de 4369
# Extraindo texto de acórdão 944 de 4369
# Extraindo texto de acórdão 945 de 4369
# Extraindo texto de acórdão 946 de 4369
# Extraindo texto de acórdão 947 de 4369
# Extraindo texto de acórdão 948 de 4369
# Extraindo texto de acórdão 949 de 4369
# Extraindo texto de acórdão 950 de 4369
# Extraindo texto de acórdão 951 de 4369
# Extraindo texto de acórdão 952 de 4369
# Extraindo texto de acórdão 953 de 4369
# Extraindo texto de acórdão 954 de 4369
# Extraindo texto de acórdão 955 de 4369
# Extraindo texto de acórdão 956 de 4369
# Extraindo texto de acórdão 957 de 4369
# Extraindo texto de acórdão 958 de 4369
# Extraindo texto de acórdão 959 de 4369
# Extraindo texto de acórdão 960 de 4369
# Extraindo texto de acórdão 961 de 4369
# Extraindo texto de acórdão 962 de 4369
# Extraindo texto de acórdão 963 de 4369
# Extraindo texto de acórdão 964 de 4369
# Extraindo texto de acórdão 965 de 4369
# Extraindo texto de acórdão 966 de 4369
# Extraindo texto de acórdão 967 de 4369
# Extraindo texto de acórdão 968 de 4369
# Extraindo texto de acórdão 969 de 4369
# Extraindo texto de acórdão 970 de 4369
# Extraindo texto de acórdão 971 de 4369
# Extraindo texto de acórdão 972 de 4369
# Extraindo texto de acórdão 973 de 4369
# Extraindo texto de acórdão 974 de 4369
# Extraindo texto de acórdão 975 de 4369
# Extraindo texto de acórdão 976 de 4369
# Extraindo texto de acórdão 977 de 4369
# Extraindo texto de acórdão 978 de 4369
# Extraindo texto de acórdão 979 de 4369
# Extraindo texto de acórdão 980 de 4369
# Extraindo texto de acórdão 981 de 4369
# Extraindo texto de acórdão 982 de 4369
# Extraindo texto de acórdão 983 de 4369
# Extraindo texto de acórdão 984 de 4369
# Extraindo texto de acórdão 985 de 4369
# Extraindo texto de acórdão 986 de 4369
# Extraindo texto de acórdão 987 de 4369
# Extraindo texto de acórdão 988 de 4369
# Extraindo texto de acórdão 989 de 4369
# Extraindo texto de acórdão 990 de 4369
# Extraindo texto de acórdão 991 de 4369
# Extraindo texto de acórdão 992 de 4369
# Extraindo texto de acórdão 993 de 4369
# Extraindo texto de acórdão 994 de 4369
# Extraindo texto de acórdão 995 de 4369
# Extraindo texto de acórdão 996 de 4369
# Extraindo texto de acórdão 997 de 4369
# Extraindo texto de acórdão 998 de 4369
# Extraindo texto de acórdão 999 de 4369
# Extraindo texto de acórdão 1000 de 4369
# Extraindo texto de acórdão 1001 de 4369
# Extraindo texto de acórdão 1002 de 4369
# Extraindo texto de acórdão 1003 de 4369
# Extraindo texto de acórdão 1004 de 4369
# Extraindo texto de acórdão 1005 de 4369
# Extraindo texto de acórdão 1006 de 4369
# Extraindo texto de acórdão 1007 de 4369
# Extraindo texto de acórdão 1008 de 4369
# Extraindo texto de acórdão 1009 de 4369
# Extraindo texto de acórdão 1010 de 4369
# Extraindo texto de acórdão 1011 de 4369
# Extraindo texto de acórdão 1012 de 4369
# Extraindo texto de acórdão 1013 de 4369
# Extraindo texto de acórdão 1014 de 4369
# Extraindo texto de acórdão 1015 de 4369
# Extraindo texto de acórdão 1016 de 4369
# Extraindo texto de acórdão 1017 de 4369
# Extraindo texto de acórdão 1018 de 4369
# Extraindo texto de acórdão 1019 de 4369
# Extraindo texto de acórdão 1020 de 4369
# Extraindo texto de acórdão 1021 de 4369
# Extraindo texto de acórdão 1022 de 4369
# Extraindo texto de acórdão 1023 de 4369
# Extraindo texto de acórdão 1024 de 4369
# Extraindo texto de acórdão 1025 de 4369
# Extraindo texto de acórdão 1026 de 4369
# Extraindo texto de acórdão 1027 de 4369
# Extraindo texto de acórdão 1028 de 4369
# Extraindo texto de acórdão 1029 de 4369
# Extraindo texto de acórdão 1030 de 4369
# Extraindo texto de acórdão 1031 de 4369
# Extraindo texto de acórdão 1032 de 4369
# Extraindo texto de acórdão 1033 de 4369
# Extraindo texto de acórdão 1034 de 4369
# Extraindo texto de acórdão 1035 de 4369
# Extraindo texto de acórdão 1036 de 4369
# Extraindo texto de acórdão 1037 de 4369
# Extraindo texto de acórdão 1038 de 4369
# Extraindo texto de acórdão 1039 de 4369
# Extraindo texto de acórdão 1040 de 4369
# Extraindo texto de acórdão 1041 de 4369
# Extraindo texto de acórdão 1042 de 4369
# Extraindo texto de acórdão 1043 de 4369
# Extraindo texto de acórdão 1044 de 4369
# Extraindo texto de acórdão 1045 de 4369
# Extraindo texto de acórdão 1046 de 4369
# Extraindo texto de acórdão 1047 de 4369
# Extraindo texto de acórdão 1048 de 4369
# Extraindo texto de acórdão 1049 de 4369
# Extraindo texto de acórdão 1050 de 4369
# Extraindo texto de acórdão 1051 de 4369
# Extraindo texto de acórdão 1052 de 4369
# Extraindo texto de acórdão 1053 de 4369
# Extraindo texto de acórdão 1054 de 4369
# Extraindo texto de acórdão 1055 de 4369
# Extraindo texto de acórdão 1056 de 4369
# Extraindo texto de acórdão 1057 de 4369
# Extraindo texto de acórdão 1058 de 4369
# Extraindo texto de acórdão 1059 de 4369
# Extraindo texto de acórdão 1060 de 4369
# Extraindo texto de acórdão 1061 de 4369
# Extraindo texto de acórdão 1062 de 4369
# Extraindo texto de acórdão 1063 de 4369
# Extraindo texto de acórdão 1064 de 4369
# Extraindo texto de acórdão 1065 de 4369
# Extraindo texto de acórdão 1066 de 4369
# Extraindo texto de acórdão 1067 de 4369
# Extraindo texto de acórdão 1068 de 4369
# Extraindo texto de acórdão 1069 de 4369
# Extraindo texto de acórdão 1070 de 4369
# Extraindo texto de acórdão 1071 de 4369
# Extraindo texto de acórdão 1072 de 4369
# Extraindo texto de acórdão 1073 de 4369
# Extraindo texto de acórdão 1074 de 4369
# Extraindo texto de acórdão 1075 de 4369
# Extraindo texto de acórdão 1076 de 4369
# Extraindo texto de acórdão 1077 de 4369
# Extraindo texto de acórdão 1078 de 4369
# Extraindo texto de acórdão 1079 de 4369
# Extraindo texto de acórdão 1080 de 4369
# Extraindo texto de acórdão 1081 de 4369
# Extraindo texto de acórdão 1082 de 4369
# Extraindo texto de acórdão 1083 de 4369
# Extraindo texto de acórdão 1084 de 4369
# Extraindo texto de acórdão 1085 de 4369
# Extraindo texto de acórdão 1086 de 4369
# Extraindo texto de acórdão 1087 de 4369
# Extraindo texto de acórdão 1088 de 4369
# Extraindo texto de acórdão 1089 de 4369
# Extraindo texto de acórdão 1090 de 4369
# Extraindo texto de acórdão 1091 de 4369
# Extraindo texto de acórdão 1092 de 4369
# Extraindo texto de acórdão 1093 de 4369
# Extraindo texto de acórdão 1094 de 4369
# Extraindo texto de acórdão 1095 de 4369
# Extraindo texto de acórdão 1096 de 4369
# Extraindo texto de acórdão 1097 de 4369
# Extraindo texto de acórdão 1098 de 4369
# Extraindo texto de acórdão 1099 de 4369
# Extraindo texto de acórdão 1100 de 4369
# Extraindo texto de acórdão 1101 de 4369
# Extraindo texto de acórdão 1102 de 4369
# Extraindo texto de acórdão 1103 de 4369
# Extraindo texto de acórdão 1104 de 4369
# Extraindo texto de acórdão 1105 de 4369
# Extraindo texto de acórdão 1106 de 4369
# Extraindo texto de acórdão 1107 de 4369
# Extraindo texto de acórdão 1108 de 4369
# Extraindo texto de acórdão 1109 de 4369
# Extraindo texto de acórdão 1110 de 4369
# Extraindo texto de acórdão 1111 de 4369
# Extraindo texto de acórdão 1112 de 4369
# Extraindo texto de acórdão 1113 de 4369
# Extraindo texto de acórdão 1114 de 4369
# Extraindo texto de acórdão 1115 de 4369
# Extraindo texto de acórdão 1116 de 4369
# Extraindo texto de acórdão 1117 de 4369
# Extraindo texto de acórdão 1118 de 4369
# Extraindo texto de acórdão 1119 de 4369
# Extraindo texto de acórdão 1120 de 4369
# Extraindo texto de acórdão 1121 de 4369
# Extraindo texto de acórdão 1122 de 4369
# Extraindo texto de acórdão 1123 de 4369
# Extraindo texto de acórdão 1124 de 4369
# Extraindo texto de acórdão 1125 de 4369
# Extraindo texto de acórdão 1126 de 4369
# Extraindo texto de acórdão 1127 de 4369
# Extraindo texto de acórdão 1128 de 4369
# Extraindo texto de acórdão 1129 de 4369
# Extraindo texto de acórdão 1130 de 4369
# Extraindo texto de acórdão 1131 de 4369
# Extraindo texto de acórdão 1132 de 4369
# Extraindo texto de acórdão 1133 de 4369
# Extraindo texto de acórdão 1134 de 4369
# Extraindo texto de acórdão 1135 de 4369
# Extraindo texto de acórdão 1136 de 4369
# Extraindo texto de acórdão 1137 de 4369
# Extraindo texto de acórdão 1138 de 4369
# Extraindo texto de acórdão 1139 de 4369
# Extraindo texto de acórdão 1140 de 4369
# Extraindo texto de acórdão 1141 de 4369
# Extraindo texto de acórdão 1142 de 4369
# Extraindo texto de acórdão 1143 de 4369
# Extraindo texto de acórdão 1144 de 4369
# Extraindo texto de acórdão 1145 de 4369
# Extraindo texto de acórdão 1146 de 4369
# Extraindo texto de acórdão 1147 de 4369
# Extraindo texto de acórdão 1148 de 4369
# Extraindo texto de acórdão 1149 de 4369
# Extraindo texto de acórdão 1150 de 4369
# Extraindo texto de acórdão 1151 de 4369
# Extraindo texto de acórdão 1152 de 4369
# Extraindo texto de acórdão 1153 de 4369
# Extraindo texto de acórdão 1154 de 4369
# Extraindo texto de acórdão 1155 de 4369
# Extraindo texto de acórdão 1156 de 4369
# Extraindo texto de acórdão 1157 de 4369
# Extraindo texto de acórdão 1158 de 4369
# Extraindo texto de acórdão 1159 de 4369
# Extraindo texto de acórdão 1160 de 4369
# Extraindo texto de acórdão 1161 de 4369
# Extraindo texto de acórdão 1162 de 4369
# Extraindo texto de acórdão 1163 de 4369
# Extraindo texto de acórdão 1164 de 4369
# Extraindo texto de acórdão 1165 de 4369
# Extraindo texto de acórdão 1166 de 4369
# Extraindo texto de acórdão 1167 de 4369
# Extraindo texto de acórdão 1168 de 4369
# Extraindo texto de acórdão 1169 de 4369
# Extraindo texto de acórdão 1170 de 4369
# Extraindo texto de acórdão 1171 de 4369
# Extraindo texto de acórdão 1172 de 4369
# Extraindo texto de acórdão 1173 de 4369
# Extraindo texto de acórdão 1174 de 4369
# Extraindo texto de acórdão 1175 de 4369
# Extraindo texto de acórdão 1176 de 4369
# Extraindo texto de acórdão 1177 de 4369
# Extraindo texto de acórdão 1178 de 4369
# Extraindo texto de acórdão 1179 de 4369
# Extraindo texto de acórdão 1180 de 4369
# Extraindo texto de acórdão 1181 de 4369
# Extraindo texto de acórdão 1182 de 4369
# Extraindo texto de acórdão 1183 de 4369
# Extraindo texto de acórdão 1184 de 4369
# Extraindo texto de acórdão 1185 de 4369
# Extraindo texto de acórdão 1186 de 4369
# Extraindo texto de acórdão 1187 de 4369
# Extraindo texto de acórdão 1188 de 4369
# Extraindo texto de acórdão 1189 de 4369
# Extraindo texto de acórdão 1190 de 4369
# Extraindo texto de acórdão 1191 de 4369
# Extraindo texto de acórdão 1192 de 4369
# Extraindo texto de acórdão 1193 de 4369
# Extraindo texto de acórdão 1194 de 4369
# Extraindo texto de acórdão 1195 de 4369
# Extraindo texto de acórdão 1196 de 4369
# Extraindo texto de acórdão 1197 de 4369
# Extraindo texto de acórdão 1198 de 4369
# Extraindo texto de acórdão 1199 de 4369
# Extraindo texto de acórdão 1200 de 4369
# Extraindo texto de acórdão 1201 de 4369
# Extraindo texto de acórdão 1202 de 4369
# Extraindo texto de acórdão 1203 de 4369
# Extraindo texto de acórdão 1204 de 4369
# Extraindo texto de acórdão 1205 de 4369
# Extraindo texto de acórdão 1206 de 4369
# Extraindo texto de acórdão 1207 de 4369
# Extraindo texto de acórdão 1208 de 4369
# Extraindo texto de acórdão 1209 de 4369
# Extraindo texto de acórdão 1210 de 4369
# Extraindo texto de acórdão 1211 de 4369
# Extraindo texto de acórdão 1212 de 4369
# Extraindo texto de acórdão 1213 de 4369
# Extraindo texto de acórdão 1214 de 4369
# Extraindo texto de acórdão 1215 de 4369
# Extraindo texto de acórdão 1216 de 4369
# Extraindo texto de acórdão 1217 de 4369
# Extraindo texto de acórdão 1218 de 4369
# Extraindo texto de acórdão 1219 de 4369
# Extraindo texto de acórdão 1220 de 4369
# Extraindo texto de acórdão 1221 de 4369
# Extraindo texto de acórdão 1222 de 4369
# Extraindo texto de acórdão 1223 de 4369
# Extraindo texto de acórdão 1224 de 4369
# Extraindo texto de acórdão 1225 de 4369
# Extraindo texto de acórdão 1226 de 4369
# Extraindo texto de acórdão 1227 de 4369
# ...
# Extraindo texto de acórdão 3970 de 4369
# Extraindo texto de acórdão 3971 de 4369
# Extraindo texto de acórdão 3972 de 4369
# Extraindo texto de acórdão 3973 de 4369
# Extraindo texto de acórdão 3974 de 4369
# Extraindo texto de acórdão 3975 de 4369
# Extraindo texto de acórdão 3976 de 4369
# Extraindo texto de acórdão 3977 de 4369
# Extraindo texto de acórdão 3978 de 4369
# Extraindo texto de acórdão 3979 de 4369
# Extraindo texto de acórdão 3980 de 4369
# Extraindo texto de acórdão 3981 de 4369
# Extraindo texto de acórdão 3982 de 4369
# Extraindo texto de acórdão 3983 de 4369
# Extraindo texto de acórdão 3984 de 4369
# Extraindo texto de acórdão 3985 de 4369
# Extraindo texto de acórdão 3986 de 4369
# Extraindo texto de acórdão 3987 de 4369
# Extraindo texto de acórdão 3988 de 4369
# Extraindo texto de acórdão 3989 de 4369
# Extraindo texto de acórdão 3990 de 4369
# Extraindo texto de acórdão 3991 de 4369
# Extraindo texto de acórdão 3992 de 4369
# Extraindo texto de acórdão 3993 de 4369
# Extraindo texto de acórdão 3994 de 4369
# Extraindo texto de acórdão 3995 de 4369
# Extraindo texto de acórdão 3996 de 4369
# Extraindo texto de acórdão 3997 de 4369
# Extraindo texto de acórdão 3998 de 4369
# Extraindo texto de acórdão 3999 de 4369
# Extraindo texto de acórdão 4000 de 4369
# Extraindo texto de acórdão 4001 de 4369
# Extraindo texto de acórdão 4002 de 4369
# Extraindo texto de acórdão 4003 de 4369
# Extraindo texto de acórdão 4004 de 4369
# Extraindo texto de acórdão 4005 de 4369
# Extraindo texto de acórdão 4006 de 4369
# Extraindo texto de acórdão 4007 de 4369
# Extraindo texto de acórdão 4008 de 4369
# Extraindo texto de acórdão 4009 de 4369
# Extraindo texto de acórdão 4010 de 4369
# Extraindo texto de acórdão 4011 de 4369
# Extraindo texto de acórdão 4012 de 4369
# Extraindo texto de acórdão 4013 de 4369
# Extraindo texto de acórdão 4014 de 4369
# Extraindo texto de acórdão 4015 de 4369
# Extraindo texto de acórdão 4016 de 4369
# Extraindo texto de acórdão 4017 de 4369
# Extraindo texto de acórdão 4018 de 4369
# Extraindo texto de acórdão 4019 de 4369
# Extraindo texto de acórdão 4020 de 4369
# Extraindo texto de acórdão 4021 de 4369
# Extraindo texto de acórdão 4022 de 4369
# Extraindo texto de acórdão 4023 de 4369
# Extraindo texto de acórdão 4024 de 4369
# Extraindo texto de acórdão 4025 de 4369
# Extraindo texto de acórdão 4026 de 4369
# Extraindo texto de acórdão 4027 de 4369
# Extraindo texto de acórdão 4028 de 4369
# Extraindo texto de acórdão 4029 de 4369
# Extraindo texto de acórdão 4030 de 4369
# Extraindo texto de acórdão 4031 de 4369
# Extraindo texto de acórdão 4032 de 4369
# Extraindo texto de acórdão 4033 de 4369
# Extraindo texto de acórdão 4034 de 4369
# Extraindo texto de acórdão 4035 de 4369
# Extraindo texto de acórdão 4036 de 4369
# Extraindo texto de acórdão 4037 de 4369
# Extraindo texto de acórdão 4038 de 4369
# Extraindo texto de acórdão 4039 de 4369
# Extraindo texto de acórdão 4040 de 4369
# Extraindo texto de acórdão 4041 de 4369
# Extraindo texto de acórdão 4042 de 4369
# Extraindo texto de acórdão 4043 de 4369
# Extraindo texto de acórdão 4044 de 4369
# Extraindo texto de acórdão 4045 de 4369
# Extraindo texto de acórdão 4046 de 4369
# Extraindo texto de acórdão 4047 de 4369
# Extraindo texto de acórdão 4048 de 4369
# Extraindo texto de acórdão 4049 de 4369
# Extraindo texto de acórdão 4050 de 4369
# Extraindo texto de acórdão 4051 de 4369
# Extraindo texto de acórdão 4052 de 4369
# Extraindo texto de acórdão 4053 de 4369
# Extraindo texto de acórdão 4054 de 4369
# Extraindo texto de acórdão 4055 de 4369
# Extraindo texto de acórdão 4056 de 4369
# Extraindo texto de acórdão 4057 de 4369
# Extraindo texto de acórdão 4058 de 4369
# Extraindo texto de acórdão 4059 de 4369
# Extraindo texto de acórdão 4060 de 4369
# Extraindo texto de acórdão 4061 de 4369
# Extraindo texto de acórdão 4062 de 4369
# Extraindo texto de acórdão 4063 de 4369
# Extraindo texto de acórdão 4064 de 4369
# Extraindo texto de acórdão 4065 de 4369
# Extraindo texto de acórdão 4066 de 4369
# Extraindo texto de acórdão 4067 de 4369
# Extraindo texto de acórdão 4068 de 4369
# Extraindo texto de acórdão 4069 de 4369
# Extraindo texto de acórdão 4070 de 4369
# Extraindo texto de acórdão 4071 de 4369
# Extraindo texto de acórdão 4072 de 4369
# Extraindo texto de acórdão 4073 de 4369
# Extraindo texto de acórdão 4074 de 4369
# Extraindo texto de acórdão 4075 de 4369
# Extraindo texto de acórdão 4076 de 4369
# Extraindo texto de acórdão 4077 de 4369
# Extraindo texto de acórdão 4078 de 4369
# Extraindo texto de acórdão 4079 de 4369
# Extraindo texto de acórdão 4080 de 4369
# Extraindo texto de acórdão 4081 de 4369
# Extraindo texto de acórdão 4082 de 4369
# Extraindo texto de acórdão 4083 de 4369
# Extraindo texto de acórdão 4084 de 4369
# Extraindo texto de acórdão 4085 de 4369
# Extraindo texto de acórdão 4086 de 4369
# Extraindo texto de acórdão 4087 de 4369
# Extraindo texto de acórdão 4088 de 4369
# Extraindo texto de acórdão 4089 de 4369
# Extraindo texto de acórdão 4090 de 4369
# Extraindo texto de acórdão 4091 de 4369
# Extraindo texto de acórdão 4092 de 4369
# Extraindo texto de acórdão 4093 de 4369
# Extraindo texto de acórdão 4094 de 4369
# Extraindo texto de acórdão 4095 de 4369
# Extraindo texto de acórdão 4096 de 4369
# Extraindo texto de acórdão 4097 de 4369
# Extraindo texto de acórdão 4098 de 4369
# Extraindo texto de acórdão 4099 de 4369
# Extraindo texto de acórdão 4100 de 4369
# Extraindo texto de acórdão 4101 de 4369
# Extraindo texto de acórdão 4102 de 4369
# Extraindo texto de acórdão 4103 de 4369
# Extraindo texto de acórdão 4104 de 4369
# Extraindo texto de acórdão 4105 de 4369
# Extraindo texto de acórdão 4106 de 4369
# Extraindo texto de acórdão 4107 de 4369
# Extraindo texto de acórdão 4108 de 4369
# Extraindo texto de acórdão 4109 de 4369
# Extraindo texto de acórdão 4110 de 4369
# Extraindo texto de acórdão 4111 de 4369
# Extraindo texto de acórdão 4112 de 4369
# Extraindo texto de acórdão 4113 de 4369
# Extraindo texto de acórdão 4114 de 4369
# Extraindo texto de acórdão 4115 de 4369
# Extraindo texto de acórdão 4116 de 4369
# Extraindo texto de acórdão 4117 de 4369
# Extraindo texto de acórdão 4118 de 4369
# Extraindo texto de acórdão 4119 de 4369
# Extraindo texto de acórdão 4120 de 4369
# Extraindo texto de acórdão 4121 de 4369
# Extraindo texto de acórdão 4122 de 4369
# Extraindo texto de acórdão 4123 de 4369
# Extraindo texto de acórdão 4124 de 4369
# Extraindo texto de acórdão 4125 de 4369
# Extraindo texto de acórdão 4126 de 4369
# Extraindo texto de acórdão 4127 de 4369
# Extraindo texto de acórdão 4128 de 4369
# Extraindo texto de acórdão 4129 de 4369
# Extraindo texto de acórdão 4130 de 4369
# Extraindo texto de acórdão 4131 de 4369
# Extraindo texto de acórdão 4132 de 4369
# Extraindo texto de acórdão 4133 de 4369
# Extraindo texto de acórdão 4134 de 4369
# Extraindo texto de acórdão 4135 de 4369
# Extraindo texto de acórdão 4136 de 4369
# Extraindo texto de acórdão 4137 de 4369
# Extraindo texto de acórdão 4138 de 4369
# Extraindo texto de acórdão 4139 de 4369
# Extraindo texto de acórdão 4140 de 4369
# Extraindo texto de acórdão 4141 de 4369
# Extraindo texto de acórdão 4142 de 4369
# Extraindo texto de acórdão 4143 de 4369
# Extraindo texto de acórdão 4144 de 4369
# Extraindo texto de acórdão 4145 de 4369
# Extraindo texto de acórdão 4146 de 4369
# Extraindo texto de acórdão 4147 de 4369
# Extraindo texto de acórdão 4148 de 4369
# Extraindo texto de acórdão 4149 de 4369
# Extraindo texto de acórdão 4150 de 4369
# Extraindo texto de acórdão 4151 de 4369
# Extraindo texto de acórdão 4152 de 4369
# Extraindo texto de acórdão 4153 de 4369
# Extraindo texto de acórdão 4154 de 4369
# Extraindo texto de acórdão 4155 de 4369
# Extraindo texto de acórdão 4156 de 4369
# Extraindo texto de acórdão 4157 de 4369
# Extraindo texto de acórdão 4158 de 4369
# Extraindo texto de acórdão 4159 de 4369
# Extraindo texto de acórdão 4160 de 4369
# Extraindo texto de acórdão 4161 de 4369
# Extraindo texto de acórdão 4162 de 4369
# Extraindo texto de acórdão 4163 de 4369
# Extraindo texto de acórdão 4164 de 4369
# Extraindo texto de acórdão 4165 de 4369
# Extraindo texto de acórdão 4166 de 4369
# Extraindo texto de acórdão 4167 de 4369
# Extraindo texto de acórdão 4168 de 4369
# Extraindo texto de acórdão 4169 de 4369
# Extraindo texto de acórdão 4170 de 4369
# Extraindo texto de acórdão 4171 de 4369
# Extraindo texto de acórdão 4172 de 4369
# Extraindo texto de acórdão 4173 de 4369
# Extraindo texto de acórdão 4174 de 4369
# Extraindo texto de acórdão 4175 de 4369
# Extraindo texto de acórdão 4176 de 4369
# Extraindo texto de acórdão 4177 de 4369
# Extraindo texto de acórdão 4178 de 4369
# Extraindo texto de acórdão 4179 de 4369
# Extraindo texto de acórdão 4180 de 4369
# Extraindo texto de acórdão 4181 de 4369
# Extraindo texto de acórdão 4182 de 4369
# Extraindo texto de acórdão 4183 de 4369
# Extraindo texto de acórdão 4184 de 4369
# Extraindo texto de acórdão 4185 de 4369
# Extraindo texto de acórdão 4186 de 4369
# Extraindo texto de acórdão 4187 de 4369
# Extraindo texto de acórdão 4188 de 4369
# Extraindo texto de acórdão 4189 de 4369
# Extraindo texto de acórdão 4190 de 4369
# Extraindo texto de acórdão 4191 de 4369
# Extraindo texto de acórdão 4192 de 4369
# Extraindo texto de acórdão 4193 de 4369
# Extraindo texto de acórdão 4194 de 4369
# Extraindo texto de acórdão 4195 de 4369
# Extraindo texto de acórdão 4196 de 4369
# Extraindo texto de acórdão 4197 de 4369
# Extraindo texto de acórdão 4198 de 4369
# Extraindo texto de acórdão 4199 de 4369
# Extraindo texto de acórdão 4200 de 4369
# Extraindo texto de acórdão 4201 de 4369
# Extraindo texto de acórdão 4202 de 4369
# Extraindo texto de acórdão 4203 de 4369
# Extraindo texto de acórdão 4204 de 4369
# Extraindo texto de acórdão 4205 de 4369
# Extraindo texto de acórdão 4206 de 4369
# Extraindo texto de acórdão 4207 de 4369
# Extraindo texto de acórdão 4208 de 4369
# Extraindo texto de acórdão 4209 de 4369
# Extraindo texto de acórdão 4210 de 4369
# Extraindo texto de acórdão 4211 de 4369
# Extraindo texto de acórdão 4212 de 4369
# Extraindo texto de acórdão 4213 de 4369
# Extraindo texto de acórdão 4214 de 4369
# Extraindo texto de acórdão 4215 de 4369
# Extraindo texto de acórdão 4216 de 4369
# Extraindo texto de acórdão 4217 de 4369
# Extraindo texto de acórdão 4218 de 4369
# Extraindo texto de acórdão 4219 de 4369
# Extraindo texto de acórdão 4220 de 4369
# Extraindo texto de acórdão 4221 de 4369
# Extraindo texto de acórdão 4222 de 4369
# Extraindo texto de acórdão 4223 de 4369
# Extraindo texto de acórdão 4224 de 4369
# Extraindo texto de acórdão 4225 de 4369
# Extraindo texto de acórdão 4226 de 4369
# Extraindo texto de acórdão 4227 de 4369
# Extraindo texto de acórdão 4228 de 4369
# Extraindo texto de acórdão 4229 de 4369
# Extraindo texto de acórdão 4230 de 4369
# Extraindo texto de acórdão 4231 de 4369
# Extraindo texto de acórdão 4232 de 4369
# Extraindo texto de acórdão 4233 de 4369
# Extraindo texto de acórdão 4234 de 4369
# Extraindo texto de acórdão 4235 de 4369
# Extraindo texto de acórdão 4236 de 4369
# Extraindo texto de acórdão 4237 de 4369
# Extraindo texto de acórdão 4238 de 4369
# Extraindo texto de acórdão 4239 de 4369
# Extraindo texto de acórdão 4240 de 4369
# Extraindo texto de acórdão 4241 de 4369
# Extraindo texto de acórdão 4242 de 4369
# Extraindo texto de acórdão 4243 de 4369
# Extraindo texto de acórdão 4244 de 4369
# Extraindo texto de acórdão 4245 de 4369
# Extraindo texto de acórdão 4246 de 4369
# Extraindo texto de acórdão 4247 de 4369
# Extraindo texto de acórdão 4248 de 4369
# Extraindo texto de acórdão 4249 de 4369
# Extraindo texto de acórdão 4250 de 4369
# Extraindo texto de acórdão 4251 de 4369
# Extraindo texto de acórdão 4252 de 4369
# Extraindo texto de acórdão 4253 de 4369
# Extraindo texto de acórdão 4254 de 4369
# Extraindo texto de acórdão 4255 de 4369
# Extraindo texto de acórdão 4256 de 4369
# Extraindo texto de acórdão 4257 de 4369
# Extraindo texto de acórdão 4258 de 4369
# Extraindo texto de acórdão 4259 de 4369
# Extraindo texto de acórdão 4260 de 4369
# Extraindo texto de acórdão 4261 de 4369
# Extraindo texto de acórdão 4262 de 4369
# Extraindo texto de acórdão 4263 de 4369
# Extraindo texto de acórdão 4264 de 4369
# Extraindo texto de acórdão 4265 de 4369
# Extraindo texto de acórdão 4266 de 4369
# Extraindo texto de acórdão 4267 de 4369
# Extraindo texto de acórdão 4268 de 4369
# Extraindo texto de acórdão 4269 de 4369
# Extraindo texto de acórdão 4270 de 4369
# Extraindo texto de acórdão 4271 de 4369
# Extraindo texto de acórdão 4272 de 4369
# Extraindo texto de acórdão 4273 de 4369
# Extraindo texto de acórdão 4274 de 4369
# Extraindo texto de acórdão 4275 de 4369
# Extraindo texto de acórdão 4276 de 4369
# Extraindo texto de acórdão 4277 de 4369
# Extraindo texto de acórdão 4278 de 4369
# Extraindo texto de acórdão 4279 de 4369
# Extraindo texto de acórdão 4280 de 4369
# Extraindo texto de acórdão 4281 de 4369
# Extraindo texto de acórdão 4282 de 4369
# Extraindo texto de acórdão 4283 de 4369
# Extraindo texto de acórdão 4284 de 4369
# Extraindo texto de acórdão 4285 de 4369
# Extraindo texto de acórdão 4286 de 4369
# Extraindo texto de acórdão 4287 de 4369
# Extraindo texto de acórdão 4288 de 4369
# Extraindo texto de acórdão 4289 de 4369
# Extraindo texto de acórdão 4290 de 4369
# Extraindo texto de acórdão 4291 de 4369
# Extraindo texto de acórdão 4292 de 4369
# Extraindo texto de acórdão 4293 de 4369
# Extraindo texto de acórdão 4294 de 4369
# Extraindo texto de acórdão 4295 de 4369
# Extraindo texto de acórdão 4296 de 4369
# Extraindo texto de acórdão 4297 de 4369
# Extraindo texto de acórdão 4298 de 4369
# Extraindo texto de acórdão 4299 de 4369
# Extraindo texto de acórdão 4300 de 4369
# Extraindo texto de acórdão 4301 de 4369
# Extraindo texto de acórdão 4302 de 4369
# Extraindo texto de acórdão 4303 de 4369
# Extraindo texto de acórdão 4304 de 4369
# Extraindo texto de acórdão 4305 de 4369
# Extraindo texto de acórdão 4306 de 4369
# Extraindo texto de acórdão 4307 de 4369
# Extraindo texto de acórdão 4308 de 4369
# Extraindo texto de acórdão 4309 de 4369
# Extraindo texto de acórdão 4310 de 4369
# Extraindo texto de acórdão 4311 de 4369
# Extraindo texto de acórdão 4312 de 4369
# Extraindo texto de acórdão 4313 de 4369
# Extraindo texto de acórdão 4314 de 4369
# Extraindo texto de acórdão 4315 de 4369
# Extraindo texto de acórdão 4316 de 4369
# Extraindo texto de acórdão 4317 de 4369
# Extraindo texto de acórdão 4318 de 4369
# Extraindo texto de acórdão 4319 de 4369
# Extraindo texto de acórdão 4320 de 4369
# Extraindo texto de acórdão 4321 de 4369
# Extraindo texto de acórdão 4322 de 4369
# Extraindo texto de acórdão 4323 de 4369
# Extraindo texto de acórdão 4324 de 4369
# Extraindo texto de acórdão 4325 de 4369
# Extraindo texto de acórdão 4326 de 4369
# Extraindo texto de acórdão 4327 de 4369
# Extraindo texto de acórdão 4328 de 4369
# Extraindo texto de acórdão 4329 de 4369
# Extraindo texto de acórdão 4330 de 4369
# Extraindo texto de acórdão 4331 de 4369
# Extraindo texto de acórdão 4332 de 4369
# Extraindo texto de acórdão 4333 de 4369
# Extraindo texto de acórdão 4334 de 4369
# Extraindo texto de acórdão 4335 de 4369
# Extraindo texto de acórdão 4336 de 4369
# Extraindo texto de acórdão 4337 de 4369
# Extraindo texto de acórdão 4338 de 4369
# Extraindo texto de acórdão 4339 de 4369
# Extraindo texto de acórdão 4340 de 4369
# Extraindo texto de acórdão 4341 de 4369
# Extraindo texto de acórdão 4342 de 4369
# Extraindo texto de acórdão 4343 de 4369
# Extraindo texto de acórdão 4344 de 4369
# Extraindo texto de acórdão 4345 de 4369
# Extraindo texto de acórdão 4346 de 4369
# Extraindo texto de acórdão 4347 de 4369
# Extraindo texto de acórdão 4348 de 4369
# Extraindo texto de acórdão 4349 de 4369
# Extraindo texto de acórdão 4350 de 4369
# Extraindo texto de acórdão 4351 de 4369
# Extraindo texto de acórdão 4352 de 4369
# Extraindo texto de acórdão 4353 de 4369
# Extraindo texto de acórdão 4354 de 4369
# Extraindo texto de acórdão 4355 de 4369
# Extraindo texto de acórdão 4356 de 4369
# Extraindo texto de acórdão 4357 de 4369
# Extraindo texto de acórdão 4358 de 4369
# Extraindo texto de acórdão 4359 de 4369
# Extraindo texto de acórdão 4360 de 4369
# Extraindo texto de acórdão 4361 de 4369
# Extraindo texto de acórdão 4362 de 4369
# Extraindo texto de acórdão 4363 de 4369
# Extraindo texto de acórdão 4364 de 4369
# Extraindo texto de acórdão 4365 de 4369
# Extraindo texto de acórdão 4366 de 4369
# Extraindo texto de acórdão 4367 de 4369
# Extraindo texto de acórdão 4368 de 4369
# Extraindo texto de acórdão 4369 de 4369

# %%
df_tre
# Out:
#           cod_TCE                                            assunto  peca  \
# 0     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 1     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 2     052937/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    32
# 3     052940/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    50
# 4     052941/2012                   PROTOCOLO GERADO AUTOMATICAMENTE    50
# ...           ...                                                ...   ...
# 4364  019160/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    16
# 4365  019161/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    16
# 4366  019162/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/002975/2016.    13
# 4367  020232/2019  RECURSO DE RECONSIDERAÇÃO REF. AO TC/003137/20...    13
# 4368  021550/2019   RECURSO DE RECONSIDERAÇÃO REF. AO TC/003310/2016    13
#
#                              descricao           tipo_ato  \
# 0     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 1     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 2     ACOCAM - AUD-DELANO  -  152/2015  ACÓRDÃO DE CÂMARA
# 3              ACO - G.WA  -  152/2015            ACÓRDÃO
# 4           ACOCAM - AUD4  -  543/2016  ACÓRDÃO DE CÂMARA
# ...                                ...                ...
# 4364    ACOPLE - GLUCIANO  -  481/2020   ACÓRDÃO DO PLENO
# 4365    ACOPLE - GLUCIANO  -  480/2020   ACÓRDÃO DO PLENO
# 4366    ACOPLE - GLUCIANO  -  482/2020   ACÓRDÃO DO PLENO
# 4367  ACOPLE - AUD-DELANO  -  362/2020   ACÓRDÃO DO PLENO
# 4368     ACOPLE - GREBELO  -  225/2020   ACÓRDÃO DO PLENO
#
#                                                 caminho  \
# 0              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 1              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 2              /2015/07/609770/120/2/482temp/ACOCAM.pdf
# 3                  /2015/12/609773/8/75/781temp/ACO.pdf
# 4              /2016/06/609774/121/2/252temp/ACOCAM.pdf
# ...                                                 ...
# 4364  /2020/01/767691/12/3/31012020_101644_08F0E4782...
# 4365  /2020/01/767692/12/3/31012020_101437_BC2F5999B...
# 4366  /2020/01/767693/12/3/31012020_101841_2391030D9...
# 4367  /2020/02//768763/120/3/12022020_103207_13CB26B...
# 4368  /2020/02//770081/13/3/11022020_141438_57ED7C7A...
#
#                                                   texto
# 0     Estado do Piauí \nTribunal de Contas \nGab. do...
# 1     Estado do Piauí \nTribunal de Contas \nGab. do...
# 2     Estado do Piauí \nTribunal de Contas \nGab. do...
# 3     Estado do Piauí \nTribunal de Contas \n       ...
# 4     Estado do Piauí \nTribunal de Contas \nGabinet...
# ...                                                 ...
# 4364  Estado do Piauí \n                \n          ...
# 4365  Estado do Piauí \n                \n          ...
# 4366  Estado do Piauí \n                \n          ...
# 4367  Estado do Piauí\nTribunal de Contas\nGab. Cons...
# 4368  Estado do Piauí\nTribunal de Contas\nACÓRDÃO N...
#
# [4369 rows x 7 columns]

# %%
df_tre.to_csv(filename + "com-texto.csv", sep=";")

# %%
df_tre.to_csv(filename + "com-texto-utf8.csv", sep=";", encoding="UTF-8")
