# %% [markdown]
# # Análise exploratória de boletins de jurisprudência do TCE-PI

# %% [markdown]
# ## Introdução
# OBS: Foram utilizados boletins de agosto de 2017 a outubro de 2020. Tem 716 registros, 36 a mais que setembro<br>
# **Resolvi utilizar esses dados para a dissertação dissertação**. (14/11/2020)
#
# Realiza análise exploratória dos dados extraídos dos boletins de jurisprudência do TCE/PI.
#
# O dataset utilizado foi gerado a partir do notebook da importação de atos do sistema eTce por meio do script 'importa_processos_etce.py' na pasta 'src\preparation' e contém os seguintes atributos:
#
# |Campo             |Descrição                                                                                           |
# |------------------|----------------------------------------------------------------------------------------------------|
# |arquivo           |Arquivo de onde foi extraído o dado                                                                 |
# |ano_mes           |Ano e mês   obtidos a partir do campo arquivo no formato AAAA-MM                                    |
# |sumario           |Sumário do   boletim                                                                                |
# |ementa            |Ementa da   decisão proferida                                                                       |
# |informacoes       |Informações   do processo                                                                           |
# |área_tematica     |Assunto da   decisão (variável alvo)                                                                |
# |decisao_tipo      |Tipo da   decisão proferida                                                                         |
# |decisao_numero    |Número da   decisão proferida                                                                       |
# |decisao_ano       |Ano da   decisão proferida                                                                          |
#
# São executadas as seguintes tarefas:
# * Remoção de registros duplicados com base nos campos decisao_numero e decisao_ano;
# * Normalização e correção do atributo área_tematica;
# * Agrupamento de classes pouco representativas, resultando na criação do atributo assunto_agrupado;
# * Armazenamento do dataset resultante em "/data/processed/tcepi_decisoes_ate_10_2020.csv" para uso nas tarefas de mmodelagem
#
#
# Fonte: https://www.tce.pi.gov.br/imprensa/publicacoes/boletins-de-jurisprudencia/
#
# Criado po Antonio Filho em 13/11/2020

# %% [markdown]
# ### Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
import altair as alt

import matplotlib.pyplot as plt
from pathlib import Path

import re
import unicodedata

import os
import sys
sys.path.insert(0, os.path.abspath('../../src'))
import nlp_utils

# %matplotlib inline

# %% [markdown]
# ## Carregar os dados

# %%
caminho_dados = Path("../../data/raw/")
df = pd.read_csv(caminho_dados/"boletins_jurisprudencia2.csv", sep=";")

# %%
df.head()
# Out:
#                                              arquivo  ano_mes  \
# 0  Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
# 1  Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
# 2  Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
# 3  Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
# 4  Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
#
#                                              sumario  \
# 0  Agente Político. Variação dos subsídios dos ve...
# 1   Câmara Municipal. Elevado dispêndio com diárias.
# 2  Câmara Municipal. Impossibilidade de realizaçã...
# 3  Contabilidade. Divergência entre o saldo inici...
# 4  Contabilidade. Divergência entre o valor da am...
#
#                                               ementa  \
# 0  EMENTA. ORÇAMENTO. VARIAÇÃO DOS SUBSÍDIOS DOS ...
# 1  EMENTA. CÂMARA MUNICIPAL. DESPESA. ELEVADO VAL...
# 2  EMENTA. CÂMARA MUNICIPAL. IMPOSSIBILIDADE DA R...
# 3  EMENTA: PRESTAÇÃO DE CONTAS. ENVIO INTEMPESTIV...
# 4  EMENTA: PRESTAÇÃO DE CONTAS. FALHAS DE NATUREZ...
#
#                                          informacoes     area_tematica  \
# 0  (Prestação de Contas. Processo  – Relator: Con...   Agente Político
# 1  (Prestação de Contas. Processo  – Relator: Con...  Câmara Municipal
# 2  (Consulta. Processo  – Relator: Cons. Subst. D...  Câmara Municipal
# 3  (Prestação de Contas. Processo  – Relator: Con...     Contabilidade
# 4  (Prestação de Contas. Processo  – Relator: Con...     Contabilidade
#
#   decisao_tipo decisao_numero  decisao_ano
# 0      acordao           2400       2017.0
# 1      acordao           2348       2017.0
# 2      acordao           2711       2017.0
# 3      parecer            267       2017.0
# 4      parecer            249       2017.0

# %%
df.shape
# Out:
# (716, 9)

# %% [markdown]
# ## Análise exploratória

# %%
# Verificar se existe registro sem Ementa
df[df.ementa.isna()]
# Out:
# Empty DataFrame
# Columns: [arquivo, ano_mes, sumario, ementa, informacoes, area_tematica, decisao_tipo, decisao_numero, decisao_ano]
# Index: []

# %%
# Qtde. de registros por arquivo importado
print(f'Qtde. de arquivos: {df.arquivo.nunique()}')
df.arquivo.value_counts()
# Out:
# Qtde. de arquivos: 35
# Boletim de Jurisprudência TCE-PI - agosto 2020.docx                                       83
# Boletim de Jurisprudência TCE-PI - Setembro 2020.docx                                     75
# Boletim de Jurisprudência TCE-PI - Agosto-Dezembro - 17 - Consolidação semestral..docx    62
# Boletim de Jurisprudência TCE-PI - julho 2020 FINAL.docx                                  58
# Boletim de Jurisprudência TCE-PI - Maio - 19.docx                                         36
# Boletim de Jurisprudência TCE-PI - Outubro 2020.docx                                      36
# Boletim de Jurisprudência TCE-PI - Setembro - 18.docx                                     30
# Boletim de Jurisprudência TCE-PI - junho - 19.docx                                        24
# Boletim de Jurisprudência TCE-PI - junho 2020.docx                                        23
# Boletim de Jurisprudência TCE-PI - Dezembro-18 (definitivo).docx                          22
# Boletim de Jurisprudência TCE-PI - Outubro - 18.docx                                      20
# Boletim de Jurisprudência TCE-PI - Novembro - 18.docx                                     20
# Boletim de Jurisprudência TCE-PI - Julho - 18.docx                                        20
# Boletim de Jurisprudência TCE-PI - Agosto - 18.docx                                       18
# Boletim de Jurisprudência TCE-PI - Junho - 18.docx                                        18
# Boletim de Jurisprudência TCE-PI - julho - 19.docx                                        17
# Boletim de Jurisprudência TCE-PI - Agosto- 19.docx                                        13
# Boletim de Jurisprudência TCE-PI - Março - 18.docx                                        13
# Boletim de Jurisprudência TCE-PI - Abril - 19.docx                                        13
# Boletim de Jurisprudência TCE-PI - Março - 19.docx                                        11
# Boletim de Jurisprudência TCE-PI - Janeiro - 18.docx                                      11
# Boletim de Jurisprudência TCE-PI -MARÇO 2020.docx                                         10
# Boletim de Jurisprudência TCE-PI - Fevereiro - 18.docx                                    10
# Boletim de Jurisprudência TCE-PI - Maio - 18.docx                                         10
# Boletim de Jurisprudência TCE-PI - janeiro 2019.docx                                       9
# Boletim de Jurisprudência TCE-PI -fevereiro 2019.docx                                      9
# Boletim de Jurisprudência TCE-PI - Novembro - 19.docx                                      8
# Boletim de Jurisprudência TCE-PI - Abril - 18.docx                                         8
# Boletim de Jurisprudência TCE-PI - Dezembro-19.docx                                        6
# Boletim de Jurisprudência TCE-PI - Outubro - 19.docx                                       5
# Boletim de Jurisprudência TCE-PI - SETEMBRO - 19.docx                                      5
# Boletim de Jurisprudência TCE-PI - janeiro 2020.docx                                       4
# Boletim de Jurisprudência TCE-PI -fevereiro 2020.docx                                      3
# Boletim de Jurisprudência TCE-PI -Abril 2020.docx                                          3
# Boletim de Jurisprudência TCE-PI -maio 2020 (Iana cavalcanti).docx                         3
# Name: arquivo, dtype: int64

# %%
# Quantidade por ano e mês
qtde_por_mes = df.groupby('ano_mes')['arquivo']\
    .count()\
    .reset_index()\
    .rename(columns={'arquivo' : 'quantitativo'})
qtde_por_mes
# Out:
#     ano_mes  quantitativo
# 0   2017-12            62
# 1   2018-01            11
# 2   2018-02            10
# 3   2018-03            13
# 4   2018-04             8
# 5   2018-05            10
# 6   2018-06            18
# 7   2018-07            20
# 8   2018-08            18
# 9   2018-09            30
# 10  2018-10            20
# 11  2018-11            20
# 12  2018-12            22
# 13  2019-01             9
# 14  2019-02             9
# 15  2019-03            11
# 16  2019-04            13
# 17  2019-05            36
# 18  2019-06            24
# 19  2019-07            17
# 20  2019-08            13
# 21  2019-09             5
# 22  2019-10             5
# 23  2019-11             8
# 24  2019-12             6
# 25  2020-01             4
# 26  2020-02             3
# 27  2020-03            10
# 28  2020-04             3
# 29  2020-05             3
# 30  2020-06            23
# 31  2020-07            58
# 32  2020-08            83
# 33  2020-09            75
# 34  2020-10            36

# %%
alt.Chart(qtde_por_mes).mark_bar(opacity=0.5).encode(
    alt.X("ano_mes"),
    alt.Y("quantitativo", stack=None),
    #alt.Color('legislationType:N', legend=alt.Legend(title="Tipo do Normativo"), scale=alt.Scale(scheme='dark2')),
    tooltip=['ano_mes', 'quantitativo'],
).properties(
    title='Quantitativo de decisões por mês'
).interactive()
# Out:
# alt.Chart(...)

# %%
df[df.arquivo == 'Boletim de Jurisprudência TCE-PI - Maio - 19.docx']
# Out:
#                                                arquivo  ano_mes  \
# 312  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 313  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 314  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 315  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 316  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 317  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 318  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 319  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 320  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 321  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 322  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 323  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 324  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 325  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 326  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 327  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 328  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 329  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 330  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 331  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 332  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 333  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 334  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 335  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 336  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 337  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 338  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 339  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 340  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 341  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 342  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 343  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 344  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 345  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 346  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
# 347  Boletim de Jurisprudência TCE-PI - Maio - 19.docx  2019-05
#
#                                                sumario  \
# 312  Contabilidade. Inconsistência da análise dos b...
# 313               Contabilidade. Precatório do FUNDEF.
# 314  Contabilidade. Créditos suplementares em valor...
# 315  Contabilidade. Desequilíbrio da execução orçam...
# 316  Contrato. Sustação do contrato administrativo....
# 317  Contrato. Contratação de empresa transporte es...
# 318  Convênio. Prestação de contas dos recursos. Ob...
# 319  Convênio. Comprovação do cumprimento do objeti...
# 320  Despesa. Ilegalidade de atualização dos subsíd...
# 321  Despesa. Variação indevida no subsídio de vere...
# 322  Despesa.  Pagamento de diárias como complement...
# 323  Despesa. Despesa ilegal. Não demonstração de r...
# 324  Despesa. Despesa ilegal. Pagamento de diárias ...
# 325  Despesa. Pagamento em atraso das faturas de en...
# 326  Despesa. Encargos monetários por atraso dos re...
# 327  Despesa. Irregularidade nas contribuições prev...
# 328  Despesa. Despesa ilegal. Pagamento de diárias ...
# 329  Despesa. Descumprimento do índice de despesa c...
# 330               Despesa. Pensão de pensão por morte.
# 331  Despesa. Ilegalidade do adiantamento de despes...
# 332  Despesa. Duplicidade de pagamentos. Infração d...
# 333  Licitação. Extrato de contrato não localizado....
# 334  Licitação. Ilegalidade do fracionamento de des...
# 335  Licitação. Sobrepreço em licitação. Oneração e...
# 336  Licitação. Ausência de planilha detalhada dos ...
# 337  Pessoal. Acumulação ilegal de cargos. Processo...
# 338  Pessoal. Acumulação ilegal de cargos. Jornada ...
# 339  Pessoal. Contratação temporária irregular. Nec...
# 340  Pessoal. Contratação temporária irregular. Nec...
# 341  Pessoal. Contratação temporária irregular. Ser...
# 342      Pessoal. Cargo exclusivo de servidor efetivo.
# 343             Pessoal. Enquadramento dos servidores.
# 344  Prestação de Contas.  Reenvio de documentos de...
# 345  Processual. Elaboração o Plano Plurianual dois...
# 346  Processual. Principio da transparência Fiscal....
# 347  Processual. Não envio da norma legal que fixa ...
#
#                                                 ementa  \
# 312  PRESTAÇÃO DE CONTAS. GOVERNO. IMPROPRIEDADE VE...
# 313  DENÚNCIA. SUPOSTAS IRREGULARIDADES NA GESTÃO D...
# 314  CONTAS DE GOVERNO. OCORRÊNCIAS. ABERTURA DE CR...
# 315  CONTAS DO FMAS. EMPENHAMENTO E PAGAMENTO DE DE...
# 316  LICITAÇÃO. FALHAS APONTADAS NO CERTAME. SUSTAÇ...
# 317  REPRESENTAÇÃO. IRREGULARIDADES NA ADMINISTRAÇÃ...
# 318  PRESTAÇÃO DE CONTAS. INADIMPLÊNCIA REFERENTE À...
# 319  PROCESSUAL. AUSÊNCIA DA PRESTAÇÃO DE CONTAS. \...
# 320  PRESTAÇÃO DE CONTAS. VARIAÇÃO NO SUBSÍDIO DOS ...
# 321  PRESTAÇÃO DE CONTAS. CÂMARA MUNICIPAL DE SÃO R...
# 322  PREFEITURA MUNICIPAL. IRREGULARIDADES EM PAGAM...
# 323  DESPESA ILEGAL. DESPESAS NO VALOR REFERENTE À ...
# 324  DESPESA ILEGAL. PAGAMENTO DE DIÁRIAS A PESSOA ...
# 325  PRESTAÇÃO DE CONTAS. AUSÊNCIA E/OU IRREGULARID...
# 326  EMENTA. PRESTAÇÃO DE CONTAS. PREFEITURA MUNICI...
# 327  CHEFE DO EXECUTIVO. DÉBITO JUNTO À ELETROBRAS ...
# 328  DENÚNCIA. PESSOAL. ADIANTAMENTO DE SUBSÍDIOS. ...
# 329  PRESTAÇÃO DE CONTAS. FUNDEB DE LUZILÂNDIA. EXE...
# 330  PESSOAL. PENSÃO POR MORTE. AUSÊNCIA DO PROCESS...
# 331  DENÚNCIA. PESSOAL. ADIANTAMENTO DE SUBSÍDIOS. ...
# 332  SERVICOS DE COLETA E TRANSPORTE DE LIXO E ENTU...
# 333  LICITAÇÕES E CONTRATOS. CONTRATAÇÕES PARA ASSE...
# 334  PRESTAÇÃO DE CONTAS. FRACIONAMENTO DE DESPESAS...
# 335  AUDITORIA CONCOMITANTE. SOBREPREÇO EM LICITAÇÃ...
# 336  PRESTAÇÃO DE CONTAS DA FUNDAÇÃO UNIVERSIDADE E...
# 337  ACUMULAÇÃO REMUNERADA DE CARGOS PÚBLICOS SEM O...
# 338  DENÚNCIA. PROCEDÊNCIA. \nCaracteriza acúmulo i...
# 339  PRESTAÇÃO DE CONTAS. AUSÊNCIA DE PROCESSO LICI...
# 340  PRESTAÇÃO DE CONTAS. PREFEITURA MUNICIPAL DE S...
# 341  INSPEÇÃO CONTRATAÇÕES TEMPORÁRIAS. PROCEDÊNCIA...
# 342  DENÚNCIA. IRREGULARIDADE. PESSOAL. \nConforme ...
# 343  DENÚNCIA. SUPOSTAS IRREGULARIDADES. ENQUADRAME...
# 344  PRESTAÇÃO DE CONTAS DA EMPRESA DE GESTAO DE RE...
# 345  PREFEITURA MUNICIPAL. ATRASO NO ENVIO DO PROJE...
# 346  PRESTAÇÃO DE CONTAS. GOVERNO. IMPROPRIEDADE VE...
# 347  PRESTAÇÃO DE CONTAS. PAGAMENTOS DE ENCARGOS LE...
#
#                                            informacoes        area_tematica  \
# 312  (Prestação de Contas. Processo 6 – Relator Con...        Contabilidade
# 313  (Denúncia. Processo 7 – Relator Cons. Joaquim ...        Contabilidade
# 314  (Prestação de Contas. Processo  – Relatora: Co...        Contabilidade
# 315  (Prestação de Contas. Processo  – Relatora: Co...        Contabilidade
# 316  (Inspeção. Processo  – Relator: Cons. Subst. J...             Contrato
# 317  (Prestação de Contas. Processo  – Relator: Con...             Contrato
# 318  (Representação. Processo 7 – Relator: Cons. Kl...             Convênio
# 319  (Recurso. Processo 9 – Relator: Cons. Subst. J...             Convênio
# 320  (Prestação de Contas. Processo  – Relator: Con...              Despesa
# 321  (Prestação de Contas. Processo  – Relatora: Co...              Despesa
# 322  (Denúncia. Processo  – Relatora: Consª. Waltân...              Despesa
# 323  (Denúncia. Processo  – Relator: Cons. Luciano ...              Despesa
# 324  (Denúncia. Processo  – Relator: Cons. Luciano ...              Despesa
# 325  (Prestação de Contas. Processo  – Relator: Con...              Despesa
# 326  (Prestação de Contas. Processo  – Relatora: Co...              Despesa
# 327  (Prestação de Contas. Processo  – Relatora: Co...              Despesa
# 328  (Denúncia. Processo  – Relator: Cons. Kleber D...              Despesa
# 329  (Prestação de Contas. Processo  – Relatora: Co...              Despesa
# 330  (Pensão por morte. Processo  – Relator: Cons. ...              Despesa
# 331  (Denúncia. Processo  – Relator: Cons. Kleber D...              Despesa
# 332  (Representação. Processo  – Relator: Cons. Sub...              Despesa
# 333  (Prestação de Contas. Processo  – Relator: Con...            Licitação
# 334  (Prestação de Contas. Processo  – Relator: Con...            Licitação
# 335  (Prestação de Contas. Processo  – Relatora: Co...            Licitação
# 336  (Prestação de Contas. Processo  – Relatora: Co...            Licitação
# 337  (Denúncia. Processo 7 – Relator: Cons. Kleber ...              Pessoal
# 338  (Denúncia. Processo  – Relator: Cons.Subst. Al...              Pessoal
# 339  (Prestação de Contas. Processo 6 – Relator Con...              Pessoal
# 340  (Prestação de Contas. Processo  – Relatora: Co...              Pessoal
# 341  (Inspeção. Processo  – Relator: Cons.Subst. Al...              Pessoal
# 342  (Denúncia. Processo  – Relator: Cons.Subst. De...              Pessoal
# 343  (Denúncia. Processo  – Relatora: Consª.Lilian ...              Pessoal
# 344  (Prestação de Contas. Processo  – Relatora: Co...  Prestação de Contas
# 345  (Representação. Processo  – Relatora: Waltânia...           Processual
# 346  (Prestação de Contas. Processo 6 – Relator Con...           Processual
# 347  (Prestação de Contas. Processo 6 – Relator Con...           Processual
#
#     decisao_tipo decisao_numero  decisao_ano
# 312      acordao            241       2019.0
# 313      acordao            241       2019.0
# 314      parecer             41       2019.0
# 315      acordao            503       2019.0
# 316      acordao            720       2019.0
# 317      acordao            750       2019.0
# 318      acordao            799       2019.0
# 319      acordao            776       2019.0
# 320      acordao            692       2019.0
# 321      acordao            657       2019.0
# 322      acordao            481       2019.0
# 323      acordao            730       2019.0
# 324      acordao            731       2019.0
# 325      acordao            721       2019.0
# 326      acordao            654       2019.0
# 327      acordao            500       2019.0
# 328      acordao            780       2019.0
# 329      acordao            571       2019.0
# 330      acordao            749       2019.0
# 331      acordao            780       2019.0
# 332      acordao            636       2019.0
# 333      acordao            685       2019.0
# 334      acordao            779       2018.0
# 335      acordao            503       2019.0
# 336      acordao            763       2019.0
# 337      acordao            679       2019.0
# 338      acordao            528       2019.0
# 339      acordao            727       2019.0
# 340      acordao            656       2019.0
# 341      acordao            496       2019.0
# 342      acordao            658       2019.0
# 343      acordao            713       2019.0
# 344      acordao            756       2019.0
# 345      acordao            565       2019.0
# 346      acordao            241       2019.0
# 347      acordao            729       2019.0

# %% [markdown]
# ### Verificação de existência de registros duplicados

# %%
qtde_por_decisao = df.groupby(['decisao_numero', 'decisao_ano'])['arquivo']\
    .count()\
    .reset_index()\
    .rename(columns={'arquivo' : 'quantitativo'})
decisoes_duplicadas = qtde_por_decisao[qtde_por_decisao['quantitativo'] > 1]
print('Quantidade de numero e ano de decisão repetidos: ', len(decisoes_duplicadas))
decisoes_duplicadas
# Out:
# Quantidade de numero e ano de decisão repetidos:  53
#     decisao_numero  decisao_ano  quantitativo
# 42            1096       2020.0             3
# 46            1100       2020.0             2
# 53            1116       2019.0             2
# 83            1165       2017.0             2
# 84            1166       2020.0             2
# 111           1208       2020.0             2
# 119           1223       2018.0             2
# 125            124       2018.0             2
# 140           1298       2018.0             2
# 162           1336       2018.0             3
# 164            134       2018.0             2
# 175           1359       2018.0             2
# 178           1364       2020.0             2
# 184           1374       2018.0             2
# 200           1400       2020.0             2
# 208            142       2018.0             2
# 210           1436       2018.0             2
# 216           1463       2018.0             2
# 223           1506       2018.0             2
# 227           1543       2018.0             2
# 228           1549       2018.0             2
# 234           1573       2018.0             2
# 235           1583       2020.0             3
# 237           1589       2018.0             2
# 239           1596       2018.0             4
# 241           1600       2018.0             2
# 242           1604       2018.0             2
# 244           1632       2018.0             2
# 246           1659       2018.0             2
# 248           1672       2018.0             2
# 249           1674       2018.0             2
# 332            241       2019.0             3
# 340           2505       2017.0             2
# 373           2936       2017.0             2
# 405            343       2020.0             2
# 407            357       2020.0             2
# 409            361       2020.0             3
# 416            382       2019.0             2
# 426             41       2019.0             2
# 446            479       2020.0             2
# 455            497       2020.0             3
# 458            503       2019.0             2
# 509            641       2020.0             2
# 521            672       2020.0             2
# 529            703       2019.0             2
# 546            739       2018.0             2
# 558            761       2020.0             2
# 567            780       2019.0             2
# 569            785       2020.0             3
# 596            865       2020.0             2
# 624            934       2020.0             2
# 625            942       2019.0             2
# 638            970       2020.0             2

# %%
# Fonte: https://thispointer.com/pandas-find-duplicate-rows-in-a-dataframe-based-on-all-or-selected-columns-using-dataframe-duplicated-in-python/
df.duplicated(['decisao_numero', 'decisao_ano'], keep='first')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 711    False
# 712    False
# 713    False
# 714    False
# 715    False
# Length: 716, dtype: bool

# %%
df[df.duplicated(['decisao_numero', 'decisao_ano'], keep='first')]
# Out:
#                                                arquivo  ano_mes  \
# 11   Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
# 40   Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
# 53   Boletim de Jurisprudência TCE-PI - Agosto-Deze...  2017-12
# 105  Boletim de Jurisprudência TCE-PI - Agosto - 18...  2018-08
# 111  Boletim de Jurisprudência TCE-PI - Agosto - 18...  2018-08
# ..                                                 ...      ...
# 623  Boletim de Jurisprudência TCE-PI - Setembro 20...  2020-09
# 624  Boletim de Jurisprudência TCE-PI - Setembro 20...  2020-09
# 627  Boletim de Jurisprudência TCE-PI - Setembro 20...  2020-09
# 659  Boletim de Jurisprudência TCE-PI - Setembro 20...  2020-09
# 695  Boletim de Jurisprudência TCE-PI - Outubro 202...  2020-10
#
#                                                sumario  \
# 11   Contrato. Prorrogação. Materiais de consumo. I...
# 40   Prestação de Contas. Envio tempestivo da maior...
# 53   Processual. Impossibilidade de análise pelo Tr...
# 105  Despesa. Restos a pagar sem comprovação financ...
# 111  Pessoal. Acumulação de cargos. Assessor jurídi...
# ..                                                 ...
# 623  Despesa. Expedição de decretos de emergência p...
# 624  Despesa. Diferença entre o índice de despesa t...
# 627  Despesa. Irregularidades em operação de crédit...
# 659      Pessoal. Aplicação da Súmula nº 05 do TCE/PI.
# 695  Licitação. O simples cancelamento de procedime...
#
#                                                 ementa  \
# 11   EMENTA. IRREGULARIDADE EM PROCESSOS LICITATÓRI...
# 40   EMENTA: PRESTAÇÃO DE CONTAS. INTEMPESTIVIDADE ...
# 53   EMENTA: PESSOAL. EXONERAÇÃO DE CONTROLADORA IN...
# 105  CONTAS DO FUNDEB. RESTOS A PAGAR SEM COMPROVAÇ...
# 111  LICITAÇÃO. CONTRATAÇÃO DE PRESTAÇÃO DE SERVIÇO...
# ..                                                 ...
# 623  CONTAS DE GESTÃO DA PREFEITURA. DESCUMPRIMENTO...
# 624  DESPESA. Diferença de 0,09% entre o índice da ...
# 627  SUPOSTAS IRREGULARIDADES EM OPERAÇÃO DE CRÉDIT...
# 659  PREVIDÊNCIA. APOSENTADORIA VOLUNTÁRIA POR IDAD...
# 695  AUSÊNCIA DOS TIPOS DE VEÍCULOS A SEREM LICITAD...
#
#                                            informacoes        area_tematica  \
# 11   (Prestação de Contas. Processo  – Relator: Con...             Contrato
# 40   (Prestação de Contas. Processo  – Relator: Con...  Prestação de Contas
# 53   (Denúncia. Processo  – Relator: Cons. Joaquim ...           Processual
# 105  (Prestação de Contas. Processo  – Relatora: Co...              Despesa
# 111  (Denúncia. Processo  – Relator: Cons. Joaquim ...              Pessoal
# ..                                                 ...                  ...
# 623  (Prestação de Contas. Processo  – Relatora: Co...              Despesa
# 624  (Prestação de Contas. Processo  – Relator: Con...              Despesa
# 627  (Embargos. Processo  – Relatora: Consª. Lilian...              Despesa
# 659  (Aposentadoria. Processo  – Relator: Cons. Sub...              Pessoal
# 695  (Denúncia. Processo  – Relatora: Consª. Lilian...            Licitação
#
#     decisao_tipo decisao_numero  decisao_ano
# 11       acordao           1165       2017.0
# 40       acordao           2505       2017.0
# 53       acordao           2936       2017.0
# 105      acordao           1223       2018.0
# 111      acordao           1298       2018.0
# ..           ...            ...          ...
# 623      acordao           1166       2020.0
# 624      acordao           1583       2020.0
# 627          NaN            NaN          NaN
# 659      acordao           1364       2020.0
# 695      acordao           1400       2020.0
#
# [64 rows x 9 columns]

# %% [markdown]
# ### Remoção dos duplicados
# Dada a existência de registros duplicados, optou-se, a principio, por sua remoção, preservando os registros mais recentes.<br>
# Fonte: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html
#
# OBS: Como os dados são poucos e há assuntos com pouca representação, decidiu-se por remover duplicatas neste momento.

# %%
#df.drop_duplicates(['decisao_numero', 'decisao_ano'], keep='last', inplace=True)

# %%
df.shape
# Out:
# (716, 9)

# %% [markdown]
# ### Análise de áreas temáticas
# Como há uma grade variedade de áreas, o que dificulta o trabalho. Vamos agrupar algumas classes.
#
# Essas são as áreas definidas em [RESOLUÇÃO TCE/PI Nº 15, de 14 de agosto de 2017](https://www.tce.pi.gov.br/wp-content/uploads/2017/08/Resolu%C3%A7%C3%A3o-n%C2%BA-15-17-Elabora%C3%A7%C3%A3o-de-ac%C3%B3rd%C3%A3os-e-ementas.pdf)
#
# |                     |  |     |  |   |
# |------------------------------------|--------------------|---------------------|---------------------|---|
# | Agente Político                    | Assistência Social | Câmara Municipal    | Consórcios Públicos |   |
# | Contabilidade                      | Contrato           | Controle Interno    | Controle Social     |   |
# | Convênio e Instrumentos Congêneres | Despesa            | Dívida Ativa        | Educação            |   |
# | Fundo Especial                     | Licitação          | Orçamento           | Patrimônio          |   |
# | Pessoal                            | Planejamento       | Prestação de Contas | Previdência         |   |
# | Processual                         | Receita            | Responsabilidade    | Saúde               |   |
# | Transparência                      | Tributação         |                     |                     |   |

# %%
# Função para normalizar texto, tirando acentuação e colocando em caixa alta
def normalize(text):
    return unicodedata.normalize("NFD", text).encode('ASCII','ignore').decode('ASCII')\
        .strip().upper()

# %%
# Qtde. de registros por área temática
print(f'Qtde. de áreas temáticas: {df.area_tematica.unique().size}')
df.area_tematica.value_counts()
# Out:
# Qtde. de áreas temáticas: 29
# Licitação                                                     132
# Pessoal                                                       129
# Despesa                                                        72
# Processual                                                     64
# Contrato                                                       48
# Prestação de Contas                                            48
# Previdência                                                    39
# Agente Político                                                32
# Responsabilidade                                               25
# Contabilidade                                                  19
# Educação                                                       16
# Câmara Municipal                                               15
# Transparência                                                  14
# Orçamento                                                      10
# Receita                                                        10
# Saúde                                                           9
# Convênio                                                        6
# Controle interno                                                6
# FUNDEF                                                          4
# Planejamento                                                    4
# FUNDEB                                                          4
# Controle Interno                                                3
# Despesas                                                        1
# Patrimônio                                                      1
# Contabilidade Descumprimento as obrigações constitucionais      1
# Representação                                                   1
# Tributação                                                      1
# Prestação de contas                                             1
# Pagamento                                                       1
# Name: area_tematica, dtype: int64

# %%
# Correção de AreaTematica em registro que não foi colocado ponto para separá-la
df.loc[df.area_tematica=='Contabilidade Descumprimento as obrigações constitucionais', 'area_tematica'] = 'Contabilidade'
df.loc[df.area_tematica=='Despesas', 'area_tematica'] = 'Despesa'

# %%
# Normalizar áreas
df.area_tematica = df.area_tematica.apply(normalize)

# %%
# Qtde. de registros por área temática após correção e normalização
print(f'Qtde. de áreas temáticas após normalização: {df.area_tematica.unique().size}')
pd.DataFrame(df.area_tematica.value_counts())
# Out:
# Qtde. de áreas temáticas após normalização: 25
#                      area_tematica
# LICITACAO                      132
# PESSOAL                        129
# DESPESA                         73
# PROCESSUAL                      64
# PRESTACAO DE CONTAS             49
# CONTRATO                        48
# PREVIDENCIA                     39
# AGENTE POLITICO                 32
# RESPONSABILIDADE                25
# CONTABILIDADE                   20
# EDUCACAO                        16
# CAMARA MUNICIPAL                15
# TRANSPARENCIA                   14
# RECEITA                         10
# ORCAMENTO                       10
# CONTROLE INTERNO                 9
# SAUDE                            9
# CONVENIO                         6
# FUNDEF                           4
# FUNDEB                           4
# PLANEJAMENTO                     4
# TRIBUTACAO                       1
# REPRESENTACAO                    1
# PAGAMENTO                        1
# PATRIMONIO                       1

# %%
qtde_por_area = df.groupby('area_tematica')['arquivo']\
    .count()\
    .reset_index()\
    .rename(columns={'area_tematica': 'assunto', 'arquivo' : 'quantitativo'})
qtde_por_area
# Out:
#                 assunto  quantitativo
# 0       AGENTE POLITICO            32
# 1      CAMARA MUNICIPAL            15
# 2         CONTABILIDADE            20
# 3              CONTRATO            48
# 4      CONTROLE INTERNO             9
# 5              CONVENIO             6
# 6               DESPESA            73
# 7              EDUCACAO            16
# 8                FUNDEB             4
# 9                FUNDEF             4
# 10            LICITACAO           132
# 11            ORCAMENTO            10
# 12            PAGAMENTO             1
# 13           PATRIMONIO             1
# 14              PESSOAL           129
# 15         PLANEJAMENTO             4
# 16  PRESTACAO DE CONTAS            49
# 17          PREVIDENCIA            39
# 18           PROCESSUAL            64
# 19              RECEITA            10
# 20        REPRESENTACAO             1
# 21     RESPONSABILIDADE            25
# 22                SAUDE             9
# 23        TRANSPARENCIA            14
# 24           TRIBUTACAO             1

# %%
alt.Chart(qtde_por_area).mark_bar().encode(
    x="quantitativo",
    y=alt.Y("assunto", sort='-x'),
    tooltip=['assunto', 'quantitativo']
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Verificação de distribuição de cauda longa

# %%
count_clf_assuntos = pd.DataFrame(df.groupby('area_tematica')['arquivo']\
                              .count()\
                              .sort_values(ascending=False)\
                              .copy())\
                              .rename(columns={'arquivo' : 'quantitativo'})
count_clf_assuntos = count_clf_assuntos.assign(
    soma_acumulada=count_clf_assuntos.quantitativo.cumsum())
count_clf_assuntos = count_clf_assuntos.assign(
    perc_acumulado= 100*count_clf_assuntos.soma_acumulada/count_clf_assuntos.quantitativo.sum(),
    rank=range(1, count_clf_assuntos.shape[0]+1)
)
count_clf_assuntos['rank'] = count_clf_assuntos['rank'].astype('category')
count_clf_assuntos.reset_index(inplace=True)
count_clf_assuntos
# Out:
#           area_tematica  quantitativo  soma_acumulada  perc_acumulado rank
# 0             LICITACAO           132             132       18.435754    1
# 1               PESSOAL           129             261       36.452514    2
# 2               DESPESA            73             334       46.648045    3
# 3            PROCESSUAL            64             398       55.586592    4
# 4   PRESTACAO DE CONTAS            49             447       62.430168    5
# 5              CONTRATO            48             495       69.134078    6
# 6           PREVIDENCIA            39             534       74.581006    7
# 7       AGENTE POLITICO            32             566       79.050279    8
# 8      RESPONSABILIDADE            25             591       82.541899    9
# 9         CONTABILIDADE            20             611       85.335196   10
# 10             EDUCACAO            16             627       87.569832   11
# 11     CAMARA MUNICIPAL            15             642       89.664804   12
# 12        TRANSPARENCIA            14             656       91.620112   13
# 13              RECEITA            10             666       93.016760   14
# 14            ORCAMENTO            10             676       94.413408   15
# 15                SAUDE             9             685       95.670391   16
# 16     CONTROLE INTERNO             9             694       96.927374   17
# 17             CONVENIO             6             700       97.765363   18
# 18         PLANEJAMENTO             4             704       98.324022   19
# 19               FUNDEF             4             708       98.882682   20
# 20               FUNDEB             4             712       99.441341   21
# 21           TRIBUTACAO             1             713       99.581006   22
# 22           PATRIMONIO             1             714       99.720670   23
# 23        REPRESENTACAO             1             715       99.860335   24
# 24            PAGAMENTO             1             716      100.000000   25

# %%
alt.Chart(count_clf_assuntos).mark_area(
    interpolate='step-after',
    line=True
).encode(
    alt.X('rank:O', axis=alt.Axis(values=[5, 10, 15, 20, 30])),
    alt.Y('quantitativo:Q'),
 #   color=alt.value(default_color_1),
).properties(
    width=400,
    height=300,
    title='Distribuição da frequência de ocorrência de assuntos'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Agrupamento de dados pouco representativos
# Percebe-se que os 9 primeiros assuntos representam mais de 82% do total de ocorrências do dataset. Em função disso, os demais 17% serão agrupado em OUTROS.
#
# Antes, porém, deve-se remover as duplicatas

# %% [markdown]
# #### Agrupando os registros

# %%
#9 principais assuntos:
count_clf_assuntos[:9]['area_tematica'].to_list()
# Out:
# ['LICITACAO',
#  'PESSOAL',
#  'DESPESA',
#  'PROCESSUAL',
#  'PRESTACAO DE CONTAS',
#  'CONTRATO',
#  'PREVIDENCIA',
#  'AGENTE POLITICO',
#  'RESPONSABILIDADE']

# %%
df['assunto_agrupado'] = df.area_tematica.apply(lambda x: x if x in count_clf_assuntos[:9]['area_tematica'].to_list() else 'OUTROS')
df.loc[:5,['area_tematica', 'assunto_agrupado']]
# Out:
#       area_tematica assunto_agrupado
# 0   AGENTE POLITICO  AGENTE POLITICO
# 1  CAMARA MUNICIPAL           OUTROS
# 2  CAMARA MUNICIPAL           OUTROS
# 3     CONTABILIDADE           OUTROS
# 4     CONTABILIDADE           OUTROS
# 5     CONTABILIDADE           OUTROS

# %%
#pd.DataFrame(pd.DataFrame(Y).groupby('area_tematica')['area_tematica'].count())
#Y = df.area_tematica.apply(lambda x: x if x in count_clf_assuntos[:10]['area_tematica'].to_list() else 'OUTROS')
#pd.DataFrame(zip(Y, df.area_tematica), columns=['y', 'area_tematica']).groupby('y')['area_tematica'].count()

# %%
qtde_assuntos_agrupados = df.groupby('assunto_agrupado')['arquivo']\
    .count()\
    .reset_index()\
    .rename(columns={'assunto_agrupado': 'assunto', 'arquivo' : 'quantitativo'})
alt_agrupados = alt.Chart(qtde_assuntos_agrupados).mark_bar().encode(
    alt.X("quantitativo"),
    alt.Y("assunto", sort='-x', title="assunto"),
    tooltip=['assunto', 'quantitativo']
).properties(height=300,
             title='Quantitativo de decisões por assunto agrupado'
)
alt_agrupados
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Remover duplicatas
# É chegada a hora de resolver o problema das duplicatas, dessa vez, com a utilização de um critério bem mais adequado do que aquele imaginado no momento da detecção do problema: a priorização pela manutenção das 9 principais áreas temáticas, em detrimento daquelas agrupadas na categoria OUTROS
#
# Portanto, Antes de remover, deve-se criar ordenação de acordo com a priorização em que os registros precisam ser mantidos:
# 1. Estar entre os 9 principais assuntos
# 2. Entre os 9, ordenar inversamente o ranking, para melhor estratificação das amostras

# %%
# Antes de remover, ordenar
#count_clf_assuntos['prioridade'] = count_clf_assuntos['rank'].apply(lambda x: (x-10)*-1 if x <= 10 else x).astype(int)
#count_clf_assuntos.sort_values('prioridade')
df_sd = pd.merge(df, count_clf_assuntos, on='area_tematica')\
    [['arquivo', 'ano_mes', 'sumario', 'ementa', 'informacoes', 'area_tematica', \
     'decisao_tipo', 'decisao_numero', 'decisao_ano', 'assunto_agrupado', 'rank']]

# %%
df_sd['prioridade'] = df_sd['rank'].apply(lambda x: (x-9)*-1 if x <= 9 else x).astype(int)
df_sd.sort_values('prioridade', inplace=True)

# %%
df_sd
# Out:
#                                                arquivo  ano_mes  \
# 641  Boletim de Jurisprudência TCE-PI - julho - 19....  2019-07
# 661  Boletim de Jurisprudência TCE-PI - Setembro 20...  2020-09
# 660  Boletim de Jurisprudência TCE-PI - Setembro 20...  2020-09
# 659  Boletim de Jurisprudência TCE-PI - junho 2020....  2020-06
# 658  Boletim de Jurisprudência TCE-PI - junho 2020....  2020-06
# ..                                                 ...      ...
# 710  Boletim de Jurisprudência TCE-PI - junho 2020....  2020-06
# 698  Boletim de Jurisprudência TCE-PI - Janeiro - 1...  2018-01
# 699  Boletim de Jurisprudência TCE-PI - Junho - 18....  2018-06
# 706  Boletim de Jurisprudência TCE-PI - Outubro - 1...  2019-10
# 715  Boletim de Jurisprudência TCE-PI - agosto 2020...  2020-08
#
#                                                sumario  \
# 641  Responsabilidade. Desvio de finalidade. Não ex...
# 661  Responsabilidade. Ausência de responsabilizaçã...
# 660  Responsabilidade. Responsabilidade solidária d...
# 659  Responsabilidade. Ausência de planejamento pel...
# 658  Responsabilidade. Não responsabilização do atu...
# ..                                                 ...
# 710  FUNDEB. Irregularidade na utilização do precat...
# 698  Tributação. Isenções fiscais de ICMS sem a rea...
# 699  Patrimônio. Inexistência de registros analític...
# 706  Representação. Prestação de contas em atraso c...
# 715  Pagamento. Pagamentos em espécie superior ao l...
#
#                                                 ementa  \
# 641  RECURSO DE RECONSIDERAÇÃO. TOMADA DE CONTAS. S...
# 661  RESPONSABILIDADE. CONTRATOS FIRMADOS ANTERIORE...
# 660  CONTROLE INTERNO DA PREFEITURA. SUBLOCAÇÃO DE ...
# 659  PRESTAÇÃO DE CONTAS. DESPESAS COM MULTAS E JUR...
# 658  AUDITORIA DE OBRAS E SERVIÇOS DE ENGENHARIA. I...
# ..                                                 ...
# 710  IRREGULARIDADES NA APLICAÇÃO DE PRECATÓRIOS DO...
# 698  EMENTA. RENÚNCIA DE RECEITAS. GUERRA FISCAL. F...
# 699  PRESTAÇÃO DE CONTAS. AUSÊNCIA DE REGISTRO PATR...
# 706  REPRESENTAÇÃO. PEDIDO DE BLOQUEIO DE CONTAS. P...
# 715  TOMADA DE CONTAS ESPECIAL. PAGAMENTOS EM ESPÉC...
#
#                                            informacoes     area_tematica  \
# 641  (Recurso de Reconsideração. Processo  – Relato...  RESPONSABILIDADE
# 661  (Pedido de Revisão. Processo  – Relator: Cons....  RESPONSABILIDADE
# 660  (Prestação de Contas. Processo  – Relatora: Co...  RESPONSABILIDADE
# 659  (Prestação de Contas. Processo  – Relator: Con...  RESPONSABILIDADE
# 658  (Auditoria. Processo  – Relator: Conselheiro J...  RESPONSABILIDADE
# ..                                                 ...               ...
# 710  (Representação. Processo 7 – Relator: Cons. Jo...            FUNDEB
# 698  (Prestação de Contas. Processo  – Relator: Con...        TRIBUTACAO
# 699  (Prestação de Contas. Processo  – Relator: Con...        PATRIMONIO
# 706  (Prestação de Contas. Processo 9 – Relator: Co...     REPRESENTACAO
# 715  (Tomada de Contas. Processo  – Relator: Cons. ...         PAGAMENTO
#
#     decisao_tipo decisao_numero  decisao_ano  assunto_agrupado rank  \
# 641      acordao           1183       2019.0  RESPONSABILIDADE    9
# 661      acordao           1129       2020.0  RESPONSABILIDADE    9
# 660      acordao           1169       2020.0  RESPONSABILIDADE    9
# 659      acordao            433       2020.0  RESPONSABILIDADE    9
# 658      acordao            506       2020.0  RESPONSABILIDADE    9
# ..           ...            ...          ...               ...  ...
# 710      acordao            582       2020.0            OUTROS   21
# 698      acordao           3085       2017.0            OUTROS   22
# 699      acordao            840       2018.0            OUTROS   23
# 706      acordao           1584       2019.0            OUTROS   24
# 715      acordao            736       2020.0            OUTROS   25
#
#      prioridade
# 641           0
# 661           0
# 660           0
# 659           0
# 658           0
# ..          ...
# 710          21
# 698          22
# 699          23
# 706          24
# 715          25
#
# [716 rows x 12 columns]

# %%
# Remover
df_sd.drop_duplicates(['decisao_numero', 'decisao_ano'], keep='first', inplace=True)

# %%
df_sd.shape
# Out:
# (652, 12)

# %%
qtde_assuntos_sem_dup = df_sd.groupby('assunto_agrupado')['arquivo']\
    .count()\
    .reset_index()\
    .rename(columns={'assunto_agrupado': 'assunto', 'arquivo' : 'quantitativo'})
alt_sem_dup = alt.Chart(qtde_assuntos_sem_dup).mark_bar().encode(
    alt.X("quantitativo"),
    alt.Y("assunto", sort='-x', title="assunto"),
    tooltip=['assunto', 'quantitativo']
).properties(height=300,
             title='Quantitativo de decisões por assunto sem duplicatas'
)
alt_sem_dup.configure_mark(color='#40A89E')
# Out:
# alt.Chart(...)

# %%
qtde_assuntos_agrupados.merge(qtde_assuntos_sem_dup, on = "assunto").set_index("assunto")\
.rename(columns = {'quantitativo_x': 'Completo', 'quantitativo_y': 'Sem-duplicados'})\
.sort_values('Completo', ascending=True)\
.plot.barh(title='Comparativo de quantitativo de assuntos', grid=True)

# %%
df_qtde_compara = pd.concat([qtde_assuntos_agrupados, qtde_assuntos_sem_dup],  ignore_index=True)
df_qtde_compara.loc[:10, 'dataset'] = 'Completo'
df_qtde_compara.loc[10:, 'dataset'] = 'Sem-Duplicados'
df_qtde_compara
# Out:
#                 assunto  quantitativo         dataset
# 0       AGENTE POLITICO            32        Completo
# 1              CONTRATO            48        Completo
# 2               DESPESA            73        Completo
# 3             LICITACAO           132        Completo
# 4                OUTROS           125        Completo
# 5               PESSOAL           129        Completo
# 6   PRESTACAO DE CONTAS            49        Completo
# 7           PREVIDENCIA            39        Completo
# 8            PROCESSUAL            64        Completo
# 9      RESPONSABILIDADE            25        Completo
# 10      AGENTE POLITICO            31  Sem-Duplicados
# 11             CONTRATO            43  Sem-Duplicados
# 12              DESPESA            65  Sem-Duplicados
# 13            LICITACAO           122  Sem-Duplicados
# 14               OUTROS           106  Sem-Duplicados
# 15              PESSOAL           118  Sem-Duplicados
# 16  PRESTACAO DE CONTAS            46  Sem-Duplicados
# 17          PREVIDENCIA            35  Sem-Duplicados
# 18           PROCESSUAL            62  Sem-Duplicados
# 19     RESPONSABILIDADE            24  Sem-Duplicados

# %%
qtde_compara = df_qtde_compara.groupby(['assunto', 'dataset'])['quantitativo']\
    .min()\
    .reset_index()\
    .rename(columns={'assunto_agrupado': 'assunto', 'arquivo' : 'quantitativo'})

# %%
qtde_compara
# Out:
#                 assunto         dataset  quantitativo
# 0       AGENTE POLITICO        Completo            32
# 1       AGENTE POLITICO  Sem-Duplicados            31
# 2              CONTRATO        Completo            48
# 3              CONTRATO  Sem-Duplicados            43
# 4               DESPESA        Completo            73
# 5               DESPESA  Sem-Duplicados            65
# 6             LICITACAO        Completo           132
# 7             LICITACAO  Sem-Duplicados           122
# 8                OUTROS        Completo           125
# 9                OUTROS  Sem-Duplicados           106
# 10              PESSOAL        Completo           129
# 11              PESSOAL  Sem-Duplicados           118
# 12  PRESTACAO DE CONTAS        Completo            49
# 13  PRESTACAO DE CONTAS  Sem-Duplicados            46
# 14          PREVIDENCIA        Completo            39
# 15          PREVIDENCIA  Sem-Duplicados            35
# 16           PROCESSUAL        Completo            64
# 17           PROCESSUAL  Sem-Duplicados            62
# 18     RESPONSABILIDADE        Completo            25
# 19     RESPONSABILIDADE  Sem-Duplicados            24

# %%
qtde_compara = df_qtde_compara.groupby(['assunto', 'dataset'])['quantitativo']\
    .min()\
    .reset_index()\
    .rename(columns={'assunto_agrupado': 'assunto', 'arquivo' : 'quantitativo'})

alt.Chart(qtde_compara).mark_bar().encode(
    x="quantitativo:Q",
    y="dataset:O",
    color='dataset',
    row = 'assunto',
).properties(title='Quantitativo de decisões por assunto sem duplicatas'
).configure_mark(color='#40A89E'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Salvar dataset para uso na etapa de modelagem

# %%
caminho = Path("../../data/processed/tcepi_decisoes_ate_10_2020.csv")
df_sd.to_csv(caminho, index=False, sep=';')
